# %%
import gym

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np

import random
import math

import collections
from collections import namedtuple

# %%
stepInfo = namedtuple('StepInfo',('cur_state', 'action','next_state', 'reward',))

class ReplayList():
    def __init__(self, size):
        self.memory = collections.deque(maxlen = size)
        
    def append(self, data):
        type(self.memory)
        self.memory.append(data)
        
    def sample(self, size):        
        if len(self.memory) < size:
            return None
        else:
            return random.sample(self.memory, size)
    
    def __len__(self):
        return len(self.memory)
    
    def __repr__(self):
        return print(self.memory)

# %%
class QNet(nn.Module):
    def __init__(self, in_size, hidden_size, out_size):
        super(QNet, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(in_size, hidden_size),
            nn.ReLU(),
#             nn.Linear(hidden_size, hidden_size),
#             nn.ReLU(),
            nn.Linear(hidden_size, out_size)
        )
        
    def forward(self,x):
        return self.net(x)

# %%
def getOneHotTensor(pos, size):
    ret = np.zeros((1,size))
    ret[0][pos] = 1
    return torch.FloatTensor(ret)#.cuda()

# %%
HIDDEN_SIZE = 32
LR = 0.0002
EPOCH = 2000

MEM_SIZE = 3000

GAMMA = 0.95
EPS_START = .9
EPS_END = 0.005
EPS_DECAY = 200

BATCH = 128
TARGET_UPDATE = 10

env = gym.make("FrozenLake-v0")

policyNet = QNet(env.observation_space.n, HIDDEN_SIZE, env.action_space.n)#.cuda()
targetNet = QNet(env.observation_space.n, HIDDEN_SIZE, env.action_space.n)#.cuda()
targetNet.load_state_dict(policyNet.state_dict())
targetNet.eval()

memory = ReplayList(MEM_SIZE)

done_size = 0

optimizer = optim.Adam(policyNet.parameters(), lr = LR)
loss = nn.MSELoss(reduction="sum")

# %%
if __name__ == "__main__":
    obs = env.reset()
    loss_list = []
    step_count = 0
    cur_target = 0
    target_list = []
    for i in range(EPOCH):
        if i%TARGET_UPDATE == 0:
            if cur_target/TARGET_UPDATE >= 0.5:
                target_list.append((i,cur_target,targetNet.state_dict()))
            else:
                targetNet.load_state_dict(policyNet.state_dict())
            cur_target = 0
            
            print(i)
        
        while True:
            eps = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * step_count / EPS_DECAY)
            if random.random()< eps:
                act = env.action_space.sample()
            else:
                with torch.no_grad():
                    Q = policyNet(getOneHotTensor(obs, env.observation_space.n))
                    act = Q.data.numpy().argmax()
            
            next_obs, rew, done, _ = env.step(act)
            step_count += 1
            if done:
                rew = rew*4 - 2
            info = stepInfo(obs, act, next_obs, rew)
            
            memory.append(info)
            replay = memory.sample(BATCH)
            
            if replay:
                replay = stepInfo(*zip(*replay))
                
                states = torch.cat(list(map(lambda s:getOneHotTensor(s,env.observation_space.n),replay.cur_state)))
                next_states = torch.cat(list(map(lambda s:getOneHotTensor(s,env.observation_space.n),replay.next_state)))
                actions = torch.cat(list(map(lambda s:getOneHotTensor(s,env.action_space.n),replay.action)))
                rewards = torch.FloatTensor(replay.reward).view(-1,1)#.cuda()
                
                optimizer.zero_grad()
                Qpred = policyNet(states)
                Qtarget = (actions * rewards + GAMMA*targetNet(next_states)).detach()
                
                loss_ = F.smooth_l1_loss(Qpred, Qtarget)
                loss_.backward()
                loss_list.append(loss_.data)
                optimizer.step()
            
            obs = next_obs
            if done:
                if rew > 0:
                    done_size += 1
                    cur_target += 1
                    print("%d, steps = %d, loss = %.4f"%(i,step_count, loss_.data), "Cleared")
                obs = env.reset()
                break
# Out:
# 0
# 10
# 20
# 30
# 39, steps = 617, loss = 0.0273 Cleared
# 40
# 50
# 60
# 70
# 80
# 90
# 100
# 110
# 120
# 126, steps = 4618, loss = 0.0035 Cleared
# 130
# 140
# 146, steps = 4733, loss = 0.0125 Cleared
# 150
# 160
# 170
# 180
# 190
# 200
# 210
# 213, steps = 5347, loss = 0.0137 Cleared
# 216, steps = 5443, loss = 0.0225 Cleared
# 220
# 222, steps = 5648, loss = 0.0211 Cleared
# 224, steps = 5689, loss = 0.0231 Cleared
# 230
# 240
# 240, steps = 6271, loss = 0.0240 Cleared
# 248, steps = 6805, loss = 0.0325 Cleared
# 249, steps = 6842, loss = 0.0257 Cleared
# 250
# 252, steps = 7005, loss = 0.0148 Cleared
# 257, steps = 7222, loss = 0.0257 Cleared
# 259, steps = 7328, loss = 0.0242 Cleared
# 260
# 261, steps = 7439, loss = 0.0151 Cleared
# 266, steps = 7700, loss = 0.0156 Cleared
# 268, steps = 7843, loss = 0.0176 Cleared
# 270
# 276, steps = 7964, loss = 0.0090 Cleared
# 280
# 280, steps = 8115, loss = 0.0089 Cleared
# 290
# 300
# 310
# 317, steps = 10413, loss = 0.0004 Cleared
# 320
# 324, steps = 10870, loss = 0.0032 Cleared
# 330
# 338, steps = 11208, loss = 0.0064 Cleared
# 340
# 350
# 355, steps = 11407, loss = 0.0046 Cleared
# 360
# 370
# 380
# 390
# 399, steps = 11846, loss = 0.0144 Cleared
# 400
# 410
# 420
# 430
# 440
# 440, steps = 12092, loss = 0.0239 Cleared
# 443, steps = 12124, loss = 0.0146 Cleared
# 445, steps = 12158, loss = 0.0076 Cleared
# 448, steps = 12187, loss = 0.0143 Cleared
# 450
# 452, steps = 12255, loss = 0.0283 Cleared
# 457, steps = 12311, loss = 0.0182 Cleared
# 460
# 463, steps = 12388, loss = 0.0236 Cleared
# 464, steps = 12396, loss = 0.0278 Cleared
# 470
# 470, steps = 12449, loss = 0.0364 Cleared
# 478, steps = 12598, loss = 0.0244 Cleared
# 479, steps = 12613, loss = 0.0231 Cleared
# 480
# 489, steps = 12740, loss = 0.0314 Cleared
# 490
# 491, steps = 12765, loss = 0.0114 Cleared
# 500
# 502, steps = 13046, loss = 0.0223 Cleared
# 506, steps = 13116, loss = 0.0278 Cleared
# 510
# 520
# 527, steps = 13544, loss = 0.0309 Cleared
# 529, steps = 13618, loss = 0.0251 Cleared
# 530
# 536, steps = 14112, loss = 0.0230 Cleared
# 538, steps = 14288, loss = 0.0324 Cleared
# 540
# 550
# 551, steps = 15030, loss = 0.0142 Cleared
# 559, steps = 15321, loss = 0.0126 Cleared
# 560
# 565, steps = 15552, loss = 0.0078 Cleared
# 566, steps = 15578, loss = 0.0068 Cleared
# 570
# 577, steps = 15935, loss = 0.0251 Cleared
# 579, steps = 15965, loss = 0.0162 Cleared
# 580
# 590
# 596, steps = 16271, loss = 0.0027 Cleared
# 599, steps = 16332, loss = 0.0138 Cleared
# 600
# 601, steps = 16370, loss = 0.0091 Cleared
# 607, steps = 16440, loss = 0.0080 Cleared
# 610
# 610, steps = 16465, loss = 0.0079 Cleared
# 613, steps = 16540, loss = 0.0070 Cleared
# 620
# 624, steps = 16774, loss = 0.0070 Cleared
# 627, steps = 16821, loss = 0.0175 Cleared
# 630
# 640
# 641, steps = 17093, loss = 0.0058 Cleared
# 650
# 660
# 661, steps = 17370, loss = 0.0160 Cleared
# 666, steps = 17700, loss = 0.0134 Cleared
# 670
# 674, steps = 18122, loss = 0.0114 Cleared
# 680
# 682, steps = 18491, loss = 0.0210 Cleared
# 683, steps = 18505, loss = 0.0238 Cleared
# 690
# 695, steps = 18785, loss = 0.0264 Cleared
# 700
# 710
# 711, steps = 19177, loss = 0.0275 Cleared
# 715, steps = 19248, loss = 0.0051 Cleared
# 716, steps = 19263, loss = 0.0180 Cleared
# 720
# 729, steps = 19570, loss = 0.0217 Cleared
# 730
# 731, steps = 19588, loss = 0.0070 Cleared
# 732, steps = 19622, loss = 0.0159 Cleared
# 734, steps = 19642, loss = 0.0088 Cleared
# 740
# 750
# 751, steps = 20105, loss = 0.0081 Cleared
# 752, steps = 20116, loss = 0.0122 Cleared
# 760
# 770
# 774, steps = 20857, loss = 0.0127 Cleared
# 780
# 788, steps = 21180, loss = 0.0168 Cleared
# 790
# 800
# 810
# 811, steps = 21548, loss = 0.0045 Cleared
# 820
# 821, steps = 21802, loss = 0.0097 Cleared
# 830
# 840
# 841, steps = 22354, loss = 0.0169 Cleared
# 844, steps = 22423, loss = 0.0061 Cleared
# 850
# 854, steps = 22599, loss = 0.0122 Cleared
# 860
# 868, steps = 23010, loss = 0.0193 Cleared
# 869, steps = 23029, loss = 0.0170 Cleared
# 870
# 876, steps = 23148, loss = 0.0282 Cleared
# 880
# 881, steps = 23304, loss = 0.0129 Cleared
# 885, steps = 23342, loss = 0.0077 Cleared
# 890
# 899, steps = 23503, loss = 0.0339 Cleared
# 900
# 910
# 920
# 930
# 934, steps = 23850, loss = 0.0312 Cleared
# 940
# 949, steps = 24015, loss = 0.0191 Cleared
# 950
# 955, steps = 24092, loss = 0.0183 Cleared
# 957, steps = 24140, loss = 0.0172 Cleared
# 960
# 963, steps = 24217, loss = 0.0174 Cleared
# 970
# 980
# 990
# 993, steps = 24930, loss = 0.0259 Cleared
# 1000
# 1007, steps = 25281, loss = 0.0244 Cleared
# 1008, steps = 25297, loss = 0.0258 Cleared
# 1009, steps = 25305, loss = 0.0229 Cleared
# 1010
# 1010, steps = 25367, loss = 0.0209 Cleared
# 1020
# 1030
# 1040
# 1041, steps = 26174, loss = 0.0119 Cleared
# 1042, steps = 26193, loss = 0.0197 Cleared
# 1046, steps = 26273, loss = 0.0228 Cleared
# 1050
# 1050, steps = 26376, loss = 0.0110 Cleared
# 1053, steps = 26488, loss = 0.0192 Cleared
# 1059, steps = 26697, loss = 0.0093 Cleared
# 1060
# 1070
# 1070, steps = 26920, loss = 0.0149 Cleared
# 1076, steps = 27172, loss = 0.0066 Cleared
# 1078, steps = 27251, loss = 0.0125 Cleared
# 1079, steps = 27275, loss = 0.0119 Cleared
# 1080
# 1082, steps = 27365, loss = 0.0076 Cleared
# 1084, steps = 27401, loss = 0.0131 Cleared
# 1086, steps = 27464, loss = 0.0170 Cleared
# 1090
# 1093, steps = 27683, loss = 0.0113 Cleared
# 1098, steps = 27839, loss = 0.0135 Cleared
# 1100
# 1108, steps = 28012, loss = 0.0059 Cleared
# 1110
# 1118, steps = 28159, loss = 0.0098 Cleared
# 1120
# 1127, steps = 28244, loss = 0.0098 Cleared
# 1130
# 1140
# 1148, steps = 28403, loss = 0.0226 Cleared
# 1150
# 1160
# 1170
# 1180
# 1188, steps = 29753, loss = 0.0263 Cleared
# 1190
# 1200
# 1206, steps = 30406, loss = 0.0193 Cleared
# 1210
# 1220
# 1230
# 1240
# 1245, steps = 31276, loss = 0.0211 Cleared
# 1248, steps = 31367, loss = 0.0206 Cleared
# 1250
# 1254, steps = 31443, loss = 0.0100 Cleared
# 1260
# 1265, steps = 31641, loss = 0.0165 Cleared
# 1270
# 1280
# 1285, steps = 32057, loss = 0.0054 Cleared
# 1288, steps = 32138, loss = 0.0128 Cleared
# 1290
# 1300
# 1303, steps = 32284, loss = 0.0197 Cleared
# 1310
# 1310, steps = 32421, loss = 0.0181 Cleared
# 1312, steps = 32448, loss = 0.0126 Cleared
# 1315, steps = 32487, loss = 0.0151 Cleared
# 1317, steps = 32519, loss = 0.0150 Cleared
# 1320
# 1326, steps = 32773, loss = 0.0147 Cleared
# 1330
# 1340
# 1350
# 1360
# 1370
# 1380
# 1380, steps = 34339, loss = 0.0096 Cleared
# 1383, steps = 34454, loss = 0.0121 Cleared
# 1390
# 1400
# 1400, steps = 35317, loss = 0.0118 Cleared
# 1410
# 1419, steps = 35562, loss = 0.0158 Cleared
# 1420
# 1427, steps = 35769, loss = 0.0114 Cleared
# 1428, steps = 35812, loss = 0.0151 Cleared
# 1430
# 1433, steps = 35906, loss = 0.0163 Cleared
# 1435, steps = 35944, loss = 0.0111 Cleared
# 1437, steps = 36011, loss = 0.0144 Cleared
# 1440
# 1450
# 1459, steps = 36455, loss = 0.0190 Cleared
# 1460
# 1466, steps = 36515, loss = 0.0176 Cleared
# 1470
# 1480
# 1488, steps = 36757, loss = 0.0175 Cleared
# 1490
# 1493, steps = 36782, loss = 0.0124 Cleared
# 1500
# 1510
# 1512, steps = 37159, loss = 0.0245 Cleared
# 1515, steps = 37283, loss = 0.0178 Cleared
# 1516, steps = 37312, loss = 0.0339 Cleared
# 1520
# 1530
# 1540
# 1550
# 1560
# 1562, steps = 38956, loss = 0.0220 Cleared
# 1570
# 1571, steps = 39292, loss = 0.0156 Cleared
# 1573, steps = 39317, loss = 0.0128 Cleared
# 1580
# 1590
# 1600
# 1609, steps = 40054, loss = 0.0103 Cleared
# 1610
# 1620
# 1629, steps = 40481, loss = 0.0139 Cleared
# 1630
# 1634, steps = 40646, loss = 0.0148 Cleared
# 1639, steps = 40866, loss = 0.0094 Cleared
# 1640
# 1640, steps = 40890, loss = 0.0147 Cleared
# 1643, steps = 40957, loss = 0.0181 Cleared
# 1646, steps = 41099, loss = 0.0089 Cleared
# 1647, steps = 41143, loss = 0.0009 Cleared
# 1648, steps = 41184, loss = 0.0078 Cleared
# 1649, steps = 41213, loss = 0.0016 Cleared
# 1650
# 1650, steps = 41225, loss = 0.0089 Cleared
# 1653, steps = 41305, loss = 0.0146 Cleared
# 1655, steps = 41377, loss = 0.0193 Cleared
# 1658, steps = 41453, loss = 0.0126 Cleared
# 1660
# 1661, steps = 41496, loss = 0.0131 Cleared
# 1670
# 1670, steps = 41632, loss = 0.0071 Cleared
# 1678, steps = 41776, loss = 0.0180 Cleared
# 1680
# 1690
# 1700
# 1710
# 1717, steps = 42099, loss = 0.0207 Cleared
# 1720
# 1730
# 1740
# 1750
# 1760
# 1770
# 1770, steps = 43866, loss = 0.0139 Cleared
# 1780
# 1790
# 1800
# 1807, steps = 45128, loss = 0.0130 Cleared
# 1810
# 1810, steps = 45237, loss = 0.0265 Cleared
# 1819, steps = 45373, loss = 0.0114 Cleared
# 1820
# 1820, steps = 45399, loss = 0.0059 Cleared
# 1821, steps = 45413, loss = 0.0070 Cleared
# 1830
# 1833, steps = 45601, loss = 0.0098 Cleared
# 1834, steps = 45624, loss = 0.0183 Cleared
# 1838, steps = 45692, loss = 0.0081 Cleared
# 1840
# 1840, steps = 45781, loss = 0.0118 Cleared
# 1847, steps = 45865, loss = 0.0126 Cleared
# 1850
# 1859, steps = 46025, loss = 0.0135 Cleared
# 1860
# 1870
# 1880
# 1890
# 1900
# 1908, steps = 46348, loss = 0.0105 Cleared
# 1910
# 1914, steps = 46408, loss = 0.0215 Cleared
# 1920
# 1924, steps = 46484, loss = 0.0221 Cleared
# 1930
# 1940
# 1950
# 1950, steps = 46795, loss = 0.0153 Cleared
# 1951, steps = 46809, loss = 0.0327 Cleared
# 1952, steps = 46820, loss = 0.0206 Cleared
# 1954, steps = 46839, loss = 0.0124 Cleared
# 1955, steps = 46853, loss = 0.0205 Cleared
# 1960
# 1970
# 1980
# 1990

# %%
for i in range(16):
    with torch.no_grad():
        print(policyNet(getOneHotTensor(i,16)).max(1)[1])
# Out:
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([3])

# %%
for i in range(16):
    with torch.no_grad():
        print(targetNet(getOneHotTensor(i,16)).max(1)[1])
# Out:
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([3])

# %%
done_size
# Out:
# 185
