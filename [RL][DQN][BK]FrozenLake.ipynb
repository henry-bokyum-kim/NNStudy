# %%
import gym

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np

import random
import math

import collections
from collections import namedtuple

# %%
stepInfo = namedtuple('StepInfo',('cur_state', 'action','next_state', 'reward',))

class ReplayList():
    def __init__(self, size):
        self.memory = collections.deque(maxlen = size)
        
    def append(self, data):
        type(self.memory)
        self.memory.append(data)
        
    def sample(self, size):        
        if len(self.memory) < size:
            return None
        else:
            return random.sample(self.memory, size)
    
    def __len__(self):
        return len(self.memory)
    
    def __repr__(self):
        return print(self.memory)

# %%
class QNet(nn.Module):
    def __init__(self, in_size, hidden_size, out_size):
        super(QNet, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(in_size, hidden_size),
            nn.ReLU(),
#             nn.Linear(hidden_size, hidden_size),
#             nn.ReLU(),
            nn.Linear(hidden_size, out_size)
        )
        
    def forward(self,x):
        return self.net(x)

# %%
def getOneHotTensor(pos, size):
    ret = np.zeros((1,size))
    ret[0][pos] = 1
    return torch.FloatTensor(ret)#.cuda()

# %%
HIDDEN_SIZE = 128
LR = 0.001
EPOCH = 2000

MEM_SIZE = 30000

GAMMA = 0.95
EPS_START = .9
EPS_END = 0.005
EPS_DECAY = 200

BATCH = 256
TARGET_UPDATE = 10

env = gym.make("FrozenLake-v0")

policyNet = QNet(env.observation_space.n, HIDDEN_SIZE, env.action_space.n)#.cuda()
targetNet = QNet(env.observation_space.n, HIDDEN_SIZE, env.action_space.n)#.cuda()
targetNet.load_state_dict(policyNet.state_dict())
targetNet.eval()

memory = ReplayList(MEM_SIZE)

done_size = 0

optimizer = optim.Adam(policyNet.parameters(), lr = LR)
loss = nn.MSELoss(reduction="sum")

# %%
if __name__ == "__main__":
    obs = env.reset()
    loss_list = []
    step_count = 0
    cur_target = 0
    target_list = []
    for i in range(EPOCH):
        if i%TARGET_UPDATE == 0:
            if cur_target/TARGET_UPDATE >= 0.5:
                target_list.append((i,cur_target,targetNet.state_dict()))
            else:
                targetNet.load_state_dict(policyNet.state_dict())
            cur_target = 0
            
            print(i)
        steps = 0
        while True:
            eps = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * step_count / EPS_DECAY)
            if random.random()< eps:
                act = env.action_space.sample()
            else:
                with torch.no_grad():
                    Q = policyNet(getOneHotTensor(obs, env.observation_space.n))
                    act = Q.data.numpy().argmax()
            
            next_obs, rew, done, _ = env.step(act)
            step_count += 1
            steps += 1
            if done:
                rew = rew*4 - 2
            info = stepInfo(obs, act, next_obs, rew)
            
            memory.append(info)
            replay = memory.sample(BATCH)
            
            if replay:
                replay = stepInfo(*zip(*replay))
                
                states = torch.cat(list(map(lambda s:getOneHotTensor(s,env.observation_space.n),replay.cur_state)))
                next_states = torch.cat(list(map(lambda s:getOneHotTensor(s,env.observation_space.n),replay.next_state)))
                actions = torch.LongTensor(replay.action).view(-1,1)
                rewards = torch.FloatTensor(replay.reward).view(-1,1)#.cuda()
                
                optimizer.zero_grad()
                Qpred = policyNet(states).gather(1, actions)
                Qtarget = rewards + GAMMA*targetNet(next_states).max(1)[0].unsqueeze(1).detach()
                
                loss_ = F.smooth_l1_loss(Qpred, Qtarget)
                loss_.backward()
                loss_list.append(loss_.data)
                optimizer.step()
            
            obs = next_obs
            if done:
                if rew > 0:
                    done_size += 1
                    cur_target += 1
                    print("%d, steps = %d, loss = %.4f"%(i, steps, loss_.data), "Cleared")
                obs = env.reset()
                break
# Out:
# 0
# 10
# 12, steps = 8, loss = 0.0494 Cleared
# 20
# 30
# 39, steps = 14, loss = 0.0510 Cleared
# 40
# 43, steps = 18, loss = 0.0725 Cleared
# 50
# 51, steps = 8, loss = 0.0529 Cleared
# 56, steps = 77, loss = 0.0380 Cleared
# 60
# 70
# 78, steps = 97, loss = 0.0204 Cleared
# 80
# 83, steps = 58, loss = 0.0167 Cleared
# 90
# 100
# 102, steps = 11, loss = 0.0126 Cleared
# 105, steps = 33, loss = 0.0269 Cleared
# 107, steps = 28, loss = 0.0195 Cleared
# 110
# 116, steps = 97, loss = 0.0261 Cleared
# 118, steps = 73, loss = 0.0130 Cleared
# 119, steps = 30, loss = 0.0207 Cleared
# 120
# 130
# 130, steps = 35, loss = 0.0162 Cleared
# 140
# 150
# 160
# 170
# 170, steps = 35, loss = 0.0201 Cleared
# 174, steps = 95, loss = 0.0230 Cleared
# 176, steps = 39, loss = 0.0116 Cleared
# 180
# 180, steps = 63, loss = 0.0173 Cleared
# 181, steps = 18, loss = 0.0339 Cleared
# 182, steps = 22, loss = 0.0252 Cleared
# 183, steps = 70, loss = 0.0421 Cleared
# 186, steps = 71, loss = 0.0170 Cleared
# 189, steps = 31, loss = 0.0292 Cleared
# 190
# 191, steps = 27, loss = 0.0290 Cleared
# 196, steps = 39, loss = 0.0075 Cleared
# 200
# 200, steps = 17, loss = 0.0294 Cleared
# 201, steps = 51, loss = 0.0173 Cleared
# 204, steps = 88, loss = 0.0145 Cleared
# 207, steps = 59, loss = 0.0303 Cleared
# 208, steps = 78, loss = 0.0398 Cleared
# 209, steps = 32, loss = 0.0176 Cleared
# 210
# 210, steps = 78, loss = 0.0189 Cleared
# 211, steps = 87, loss = 0.0170 Cleared
# 213, steps = 81, loss = 0.0179 Cleared
# 216, steps = 57, loss = 0.0246 Cleared
# 219, steps = 48, loss = 0.0160 Cleared
# 220
# 221, steps = 45, loss = 0.0154 Cleared
# 222, steps = 68, loss = 0.0202 Cleared
# 223, steps = 92, loss = 0.0289 Cleared
# 225, steps = 19, loss = 0.0245 Cleared
# 226, steps = 61, loss = 0.0289 Cleared
# 227, steps = 62, loss = 0.0376 Cleared
# 228, steps = 74, loss = 0.0199 Cleared
# 229, steps = 54, loss = 0.0189 Cleared
# 230
# 230, steps = 31, loss = 0.0277 Cleared
# 232, steps = 17, loss = 0.0249 Cleared
# 234, steps = 6, loss = 0.0136 Cleared
# 235, steps = 26, loss = 0.0101 Cleared
# 236, steps = 37, loss = 0.0417 Cleared
# 237, steps = 67, loss = 0.0357 Cleared
# 240
# 240, steps = 46, loss = 0.0223 Cleared
# 241, steps = 56, loss = 0.0248 Cleared
# 242, steps = 25, loss = 0.0292 Cleared
# 243, steps = 80, loss = 0.0339 Cleared
# 245, steps = 29, loss = 0.0294 Cleared
# 250
# 252, steps = 70, loss = 0.0159 Cleared
# 253, steps = 62, loss = 0.0131 Cleared
# 254, steps = 41, loss = 0.0348 Cleared
# 256, steps = 38, loss = 0.0179 Cleared
# 257, steps = 64, loss = 0.0301 Cleared
# 258, steps = 31, loss = 0.0113 Cleared
# 259, steps = 51, loss = 0.0246 Cleared
# 260
# 261, steps = 85, loss = 0.0176 Cleared
# 263, steps = 81, loss = 0.0370 Cleared
# 264, steps = 87, loss = 0.0240 Cleared
# 267, steps = 32, loss = 0.0163 Cleared
# 269, steps = 10, loss = 0.0512 Cleared
# 270
# 271, steps = 18, loss = 0.0157 Cleared
# 272, steps = 16, loss = 0.0244 Cleared
# 273, steps = 66, loss = 0.0331 Cleared
# 276, steps = 74, loss = 0.0425 Cleared
# 277, steps = 7, loss = 0.0155 Cleared
# 280
# 280, steps = 53, loss = 0.0353 Cleared
# 283, steps = 49, loss = 0.0304 Cleared
# 287, steps = 79, loss = 0.0308 Cleared
# 289, steps = 47, loss = 0.0487 Cleared
# 290
# 290, steps = 30, loss = 0.0216 Cleared
# 291, steps = 72, loss = 0.0233 Cleared
# 292, steps = 39, loss = 0.0336 Cleared
# 293, steps = 13, loss = 0.0470 Cleared
# 296, steps = 56, loss = 0.0241 Cleared
# 297, steps = 38, loss = 0.0472 Cleared
# 298, steps = 10, loss = 0.0240 Cleared
# 299, steps = 74, loss = 0.0108 Cleared
# 300
# 300, steps = 21, loss = 0.0085 Cleared
# 301, steps = 10, loss = 0.0243 Cleared
# 302, steps = 14, loss = 0.0315 Cleared
# 303, steps = 13, loss = 0.0313 Cleared
# 304, steps = 51, loss = 0.0159 Cleared
# 305, steps = 12, loss = 0.0218 Cleared
# 306, steps = 11, loss = 0.0245 Cleared
# 307, steps = 50, loss = 0.0145 Cleared
# 310
# 310, steps = 39, loss = 0.0239 Cleared
# 311, steps = 42, loss = 0.0252 Cleared
# 313, steps = 37, loss = 0.0299 Cleared
# 314, steps = 40, loss = 0.0147 Cleared
# 315, steps = 68, loss = 0.0306 Cleared
# 316, steps = 52, loss = 0.0213 Cleared
# 317, steps = 18, loss = 0.0201 Cleared
# 318, steps = 31, loss = 0.0234 Cleared
# 319, steps = 36, loss = 0.0193 Cleared
# 320
# 320, steps = 84, loss = 0.0297 Cleared
# 321, steps = 49, loss = 0.0476 Cleared
# 323, steps = 26, loss = 0.0257 Cleared
# 325, steps = 24, loss = 0.0131 Cleared
# 327, steps = 21, loss = 0.0182 Cleared
# 328, steps = 14, loss = 0.0251 Cleared
# 329, steps = 13, loss = 0.0084 Cleared
# 330
# 330, steps = 54, loss = 0.0140 Cleared
# 332, steps = 36, loss = 0.0149 Cleared
# 334, steps = 83, loss = 0.0336 Cleared
# 336, steps = 21, loss = 0.0191 Cleared
# 339, steps = 47, loss = 0.0250 Cleared
# 340
# 341, steps = 41, loss = 0.0278 Cleared
# 343, steps = 17, loss = 0.0235 Cleared
# 345, steps = 24, loss = 0.0229 Cleared
# 346, steps = 59, loss = 0.0330 Cleared
# 347, steps = 56, loss = 0.0246 Cleared
# 348, steps = 26, loss = 0.0394 Cleared
# 349, steps = 15, loss = 0.0187 Cleared
# 350
# 352, steps = 20, loss = 0.0156 Cleared
# 353, steps = 36, loss = 0.0450 Cleared
# 354, steps = 46, loss = 0.0237 Cleared
# 357, steps = 25, loss = 0.0220 Cleared
# 358, steps = 7, loss = 0.0419 Cleared
# 360
# 360, steps = 17, loss = 0.0149 Cleared
# 361, steps = 29, loss = 0.0130 Cleared
# 362, steps = 39, loss = 0.0275 Cleared
# 363, steps = 36, loss = 0.0269 Cleared
# 364, steps = 86, loss = 0.0179 Cleared
# 365, steps = 25, loss = 0.0285 Cleared
# 367, steps = 28, loss = 0.0261 Cleared
# 368, steps = 21, loss = 0.0272 Cleared
# 370
# 370, steps = 21, loss = 0.0231 Cleared
# 371, steps = 66, loss = 0.0205 Cleared
# 372, steps = 72, loss = 0.0359 Cleared
# 373, steps = 24, loss = 0.0223 Cleared
# 375, steps = 92, loss = 0.0279 Cleared
# 376, steps = 36, loss = 0.0298 Cleared
# 377, steps = 95, loss = 0.0322 Cleared
# 379, steps = 24, loss = 0.0217 Cleared
# 380
# 380, steps = 66, loss = 0.0405 Cleared
# 383, steps = 70, loss = 0.0162 Cleared
# 384, steps = 46, loss = 0.0138 Cleared
# 385, steps = 31, loss = 0.0242 Cleared
# 386, steps = 72, loss = 0.0299 Cleared
# 387, steps = 20, loss = 0.0288 Cleared
# 388, steps = 13, loss = 0.0096 Cleared
# 389, steps = 30, loss = 0.0247 Cleared
# 390
# 392, steps = 97, loss = 0.0342 Cleared
# 398, steps = 19, loss = 0.0150 Cleared
# 400
# 400, steps = 72, loss = 0.0233 Cleared
# 401, steps = 25, loss = 0.0104 Cleared
# 402, steps = 77, loss = 0.0269 Cleared
# 404, steps = 38, loss = 0.0247 Cleared
# 405, steps = 60, loss = 0.0198 Cleared
# 406, steps = 16, loss = 0.0272 Cleared
# 407, steps = 35, loss = 0.0264 Cleared
# 408, steps = 28, loss = 0.0161 Cleared
# 409, steps = 95, loss = 0.0188 Cleared
# 410
# 410, steps = 57, loss = 0.0255 Cleared
# 411, steps = 26, loss = 0.0238 Cleared
# 412, steps = 29, loss = 0.0204 Cleared
# 413, steps = 83, loss = 0.0156 Cleared
# 415, steps = 46, loss = 0.0096 Cleared
# 416, steps = 74, loss = 0.0327 Cleared
# 420
# 420, steps = 74, loss = 0.0073 Cleared
# 423, steps = 85, loss = 0.0298 Cleared
# 425, steps = 11, loss = 0.0255 Cleared
# 427, steps = 30, loss = 0.0221 Cleared
# 428, steps = 13, loss = 0.0353 Cleared
# 429, steps = 30, loss = 0.0315 Cleared
# 430
# 430, steps = 46, loss = 0.0259 Cleared
# 431, steps = 36, loss = 0.0394 Cleared
# 432, steps = 15, loss = 0.0251 Cleared
# 433, steps = 13, loss = 0.0350 Cleared
# 435, steps = 42, loss = 0.0152 Cleared
# 437, steps = 51, loss = 0.0199 Cleared
# 438, steps = 20, loss = 0.0111 Cleared
# 440
# 440, steps = 20, loss = 0.0278 Cleared
# 441, steps = 23, loss = 0.0453 Cleared
# 442, steps = 19, loss = 0.0145 Cleared
# 443, steps = 15, loss = 0.0284 Cleared
# 444, steps = 40, loss = 0.0240 Cleared
# 445, steps = 42, loss = 0.0514 Cleared
# 446, steps = 53, loss = 0.0241 Cleared
# 447, steps = 11, loss = 0.0098 Cleared
# 448, steps = 15, loss = 0.0169 Cleared
# 449, steps = 44, loss = 0.0271 Cleared
# 450
# 450, steps = 16, loss = 0.0167 Cleared
# 452, steps = 37, loss = 0.0186 Cleared
# 453, steps = 14, loss = 0.0170 Cleared
# 454, steps = 78, loss = 0.0152 Cleared
# 456, steps = 27, loss = 0.0290 Cleared
# 457, steps = 27, loss = 0.0270 Cleared
# 459, steps = 49, loss = 0.0197 Cleared
# 460
# 460, steps = 63, loss = 0.0196 Cleared
# 462, steps = 25, loss = 0.0236 Cleared
# 464, steps = 10, loss = 0.0152 Cleared
# 466, steps = 20, loss = 0.0128 Cleared
# 467, steps = 16, loss = 0.0260 Cleared
# 468, steps = 66, loss = 0.0248 Cleared
# 469, steps = 27, loss = 0.0250 Cleared
# 470
# 470, steps = 15, loss = 0.0228 Cleared
# 472, steps = 29, loss = 0.0267 Cleared
# 475, steps = 13, loss = 0.0231 Cleared
# 476, steps = 24, loss = 0.0264 Cleared
# 477, steps = 21, loss = 0.0148 Cleared
# 478, steps = 17, loss = 0.0369 Cleared
# 479, steps = 15, loss = 0.0356 Cleared
# 480
# 480, steps = 34, loss = 0.0255 Cleared
# 481, steps = 30, loss = 0.0260 Cleared
# 482, steps = 18, loss = 0.0283 Cleared
# 485, steps = 24, loss = 0.0210 Cleared
# 486, steps = 28, loss = 0.0200 Cleared
# 487, steps = 17, loss = 0.0268 Cleared
# 488, steps = 32, loss = 0.0251 Cleared
# 489, steps = 38, loss = 0.0173 Cleared
# 490
# 491, steps = 9, loss = 0.0278 Cleared
# 492, steps = 26, loss = 0.0302 Cleared
# 493, steps = 46, loss = 0.0272 Cleared
# 494, steps = 14, loss = 0.0266 Cleared
# 495, steps = 15, loss = 0.0110 Cleared
# 496, steps = 24, loss = 0.0276 Cleared
# 497, steps = 26, loss = 0.0222 Cleared
# 498, steps = 81, loss = 0.0179 Cleared
# 500
# 500, steps = 30, loss = 0.0253 Cleared
# 501, steps = 74, loss = 0.0284 Cleared
# 502, steps = 26, loss = 0.0229 Cleared
# 503, steps = 43, loss = 0.0239 Cleared
# 504, steps = 46, loss = 0.0286 Cleared
# 505, steps = 38, loss = 0.0288 Cleared
# 506, steps = 67, loss = 0.0243 Cleared
# 508, steps = 79, loss = 0.0247 Cleared
# 509, steps = 17, loss = 0.0316 Cleared
# 510
# 510, steps = 20, loss = 0.0265 Cleared
# 511, steps = 43, loss = 0.0260 Cleared
# 512, steps = 27, loss = 0.0170 Cleared
# 513, steps = 45, loss = 0.0207 Cleared
# 514, steps = 33, loss = 0.0288 Cleared
# 515, steps = 27, loss = 0.0276 Cleared
# 516, steps = 71, loss = 0.0309 Cleared
# 517, steps = 30, loss = 0.0184 Cleared
# 518, steps = 8, loss = 0.0437 Cleared
# 519, steps = 28, loss = 0.0236 Cleared
# 520
# 520, steps = 29, loss = 0.0283 Cleared
# 521, steps = 39, loss = 0.0237 Cleared
# 522, steps = 35, loss = 0.0247 Cleared
# 523, steps = 19, loss = 0.0224 Cleared
# 525, steps = 29, loss = 0.0168 Cleared
# 527, steps = 48, loss = 0.0141 Cleared
# 529, steps = 69, loss = 0.0160 Cleared
# 530
# 530, steps = 39, loss = 0.0191 Cleared
# 532, steps = 18, loss = 0.0240 Cleared
# 533, steps = 26, loss = 0.0329 Cleared
# 534, steps = 13, loss = 0.0279 Cleared
# 536, steps = 94, loss = 0.0243 Cleared
# 537, steps = 21, loss = 0.0437 Cleared
# 540
# 540, steps = 60, loss = 0.0380 Cleared
# 541, steps = 39, loss = 0.0242 Cleared
# 544, steps = 34, loss = 0.0250 Cleared
# 545, steps = 20, loss = 0.0157 Cleared
# 548, steps = 76, loss = 0.0218 Cleared
# 550
# 550, steps = 53, loss = 0.0348 Cleared
# 551, steps = 81, loss = 0.0214 Cleared
# 552, steps = 30, loss = 0.0294 Cleared
# 553, steps = 11, loss = 0.0406 Cleared
# 554, steps = 57, loss = 0.0254 Cleared
# 555, steps = 22, loss = 0.0238 Cleared
# 556, steps = 18, loss = 0.0332 Cleared
# 557, steps = 39, loss = 0.0317 Cleared
# 558, steps = 15, loss = 0.0220 Cleared
# 560
# 562, steps = 21, loss = 0.0199 Cleared
# 563, steps = 37, loss = 0.0284 Cleared
# 564, steps = 46, loss = 0.0241 Cleared
# 565, steps = 59, loss = 0.0127 Cleared
# 566, steps = 16, loss = 0.0259 Cleared
# 567, steps = 20, loss = 0.0306 Cleared
# 568, steps = 64, loss = 0.0220 Cleared
# 570
# 572, steps = 39, loss = 0.0154 Cleared
# 574, steps = 15, loss = 0.0215 Cleared
# 575, steps = 87, loss = 0.0113 Cleared
# 577, steps = 74, loss = 0.0118 Cleared
# 578, steps = 33, loss = 0.0215 Cleared
# 580
# 582, steps = 11, loss = 0.0262 Cleared
# 583, steps = 43, loss = 0.0377 Cleared
# 585, steps = 65, loss = 0.0333 Cleared
# 586, steps = 15, loss = 0.0241 Cleared
# 587, steps = 10, loss = 0.0176 Cleared
# 589, steps = 19, loss = 0.0327 Cleared
# 590
# 591, steps = 29, loss = 0.0242 Cleared
# 592, steps = 30, loss = 0.0341 Cleared
# 593, steps = 25, loss = 0.0341 Cleared
# 594, steps = 40, loss = 0.0341 Cleared
# 595, steps = 36, loss = 0.0280 Cleared
# 596, steps = 39, loss = 0.0197 Cleared
# 600
# 603, steps = 8, loss = 0.0302 Cleared
# 604, steps = 48, loss = 0.0143 Cleared
# 605, steps = 58, loss = 0.0317 Cleared
# 607, steps = 13, loss = 0.0252 Cleared
# 609, steps = 31, loss = 0.0313 Cleared
# 610
# 612, steps = 94, loss = 0.0242 Cleared
# 613, steps = 18, loss = 0.0327 Cleared
# 614, steps = 29, loss = 0.0179 Cleared
# 616, steps = 31, loss = 0.0275 Cleared
# 618, steps = 20, loss = 0.0359 Cleared
# 619, steps = 13, loss = 0.0229 Cleared
# 620
# 620, steps = 37, loss = 0.0257 Cleared
# 622, steps = 73, loss = 0.0347 Cleared
# 624, steps = 96, loss = 0.0277 Cleared
# 625, steps = 29, loss = 0.0206 Cleared
# 626, steps = 50, loss = 0.0188 Cleared
# 627, steps = 56, loss = 0.0346 Cleared
# 628, steps = 46, loss = 0.0263 Cleared
# 630
# 630, steps = 37, loss = 0.0235 Cleared
# 633, steps = 33, loss = 0.0284 Cleared
# 635, steps = 10, loss = 0.0408 Cleared
# 637, steps = 52, loss = 0.0224 Cleared
# 638, steps = 23, loss = 0.0155 Cleared
# 640
# 641, steps = 26, loss = 0.0316 Cleared
# 642, steps = 45, loss = 0.0256 Cleared
# 643, steps = 40, loss = 0.0129 Cleared
# 644, steps = 21, loss = 0.0208 Cleared
# 645, steps = 11, loss = 0.0187 Cleared
# 646, steps = 25, loss = 0.0235 Cleared
# 647, steps = 36, loss = 0.0260 Cleared
# 648, steps = 29, loss = 0.0479 Cleared
# 650
# 650, steps = 31, loss = 0.0417 Cleared
# 651, steps = 27, loss = 0.0157 Cleared
# 653, steps = 74, loss = 0.0243 Cleared
# 656, steps = 26, loss = 0.0178 Cleared
# 657, steps = 20, loss = 0.0173 Cleared
# 659, steps = 14, loss = 0.0255 Cleared
# 660
# 662, steps = 51, loss = 0.0371 Cleared
# 663, steps = 48, loss = 0.0198 Cleared
# 664, steps = 25, loss = 0.0176 Cleared
# 666, steps = 22, loss = 0.0303 Cleared
# 667, steps = 11, loss = 0.0151 Cleared
# 669, steps = 24, loss = 0.0269 Cleared
# 670
# 673, steps = 51, loss = 0.0325 Cleared
# 680
# 683, steps = 24, loss = 0.0178 Cleared
# 688, steps = 34, loss = 0.0230 Cleared
# 690
# 691, steps = 38, loss = 0.0237 Cleared
# 693, steps = 44, loss = 0.0263 Cleared
# 694, steps = 22, loss = 0.0126 Cleared
# 697, steps = 24, loss = 0.0229 Cleared
# 698, steps = 19, loss = 0.0451 Cleared
# 699, steps = 19, loss = 0.0131 Cleared
# 700
# 700, steps = 10, loss = 0.0344 Cleared
# 701, steps = 70, loss = 0.0386 Cleared
# 703, steps = 41, loss = 0.0314 Cleared
# 704, steps = 24, loss = 0.0336 Cleared
# 706, steps = 44, loss = 0.0398 Cleared
# 707, steps = 12, loss = 0.0127 Cleared
# 708, steps = 61, loss = 0.0171 Cleared
# 709, steps = 94, loss = 0.0187 Cleared
# 710
# 711, steps = 31, loss = 0.0358 Cleared
# 713, steps = 56, loss = 0.0306 Cleared
# 714, steps = 52, loss = 0.0174 Cleared
# 715, steps = 23, loss = 0.0424 Cleared
# 717, steps = 21, loss = 0.0140 Cleared
# 720
# 721, steps = 28, loss = 0.0410 Cleared
# 722, steps = 35, loss = 0.0273 Cleared
# 723, steps = 27, loss = 0.0161 Cleared
# 725, steps = 24, loss = 0.0326 Cleared
# 727, steps = 25, loss = 0.0251 Cleared
# 729, steps = 50, loss = 0.0336 Cleared
# 730
# 731, steps = 39, loss = 0.0205 Cleared
# 733, steps = 21, loss = 0.0265 Cleared
# 734, steps = 67, loss = 0.0254 Cleared
# 735, steps = 44, loss = 0.0338 Cleared
# 736, steps = 55, loss = 0.0242 Cleared
# 737, steps = 14, loss = 0.0235 Cleared
# 738, steps = 72, loss = 0.0175 Cleared
# 739, steps = 28, loss = 0.0369 Cleared
# 740
# 740, steps = 24, loss = 0.0212 Cleared
# 741, steps = 23, loss = 0.0287 Cleared
# 743, steps = 26, loss = 0.0327 Cleared
# 744, steps = 23, loss = 0.0373 Cleared
# 745, steps = 94, loss = 0.0265 Cleared
# 747, steps = 20, loss = 0.0250 Cleared
# 748, steps = 69, loss = 0.0192 Cleared
# 749, steps = 23, loss = 0.0355 Cleared
# 750
# 750, steps = 34, loss = 0.0227 Cleared
# 751, steps = 64, loss = 0.0238 Cleared
# 752, steps = 12, loss = 0.0292 Cleared
# 753, steps = 7, loss = 0.0253 Cleared
# 755, steps = 43, loss = 0.0347 Cleared
# 759, steps = 38, loss = 0.0188 Cleared
# 760
# 760, steps = 60, loss = 0.0188 Cleared
# 762, steps = 12, loss = 0.0296 Cleared
# 763, steps = 16, loss = 0.0156 Cleared
# 764, steps = 16, loss = 0.0264 Cleared
# 765, steps = 57, loss = 0.0285 Cleared
# 767, steps = 9, loss = 0.0404 Cleared
# 768, steps = 14, loss = 0.0296 Cleared
# 770
# 772, steps = 84, loss = 0.0175 Cleared
# 773, steps = 58, loss = 0.0301 Cleared
# 780
# 780, steps = 32, loss = 0.0385 Cleared
# 781, steps = 35, loss = 0.0189 Cleared
# 783, steps = 16, loss = 0.0319 Cleared
# 785, steps = 57, loss = 0.0297 Cleared
# 787, steps = 61, loss = 0.0207 Cleared
# 789, steps = 29, loss = 0.0329 Cleared
# 790
# 790, steps = 24, loss = 0.0252 Cleared
# 791, steps = 25, loss = 0.0270 Cleared
# 792, steps = 38, loss = 0.0210 Cleared
# 793, steps = 100, loss = 0.0169 Cleared
# 795, steps = 33, loss = 0.0236 Cleared
# 798, steps = 42, loss = 0.0482 Cleared
# 800
# 800, steps = 37, loss = 0.0163 Cleared
# 801, steps = 69, loss = 0.0253 Cleared
# 802, steps = 6, loss = 0.0298 Cleared
# 803, steps = 58, loss = 0.0415 Cleared
# 805, steps = 13, loss = 0.0388 Cleared
# 806, steps = 25, loss = 0.0239 Cleared
# 807, steps = 36, loss = 0.0368 Cleared
# 808, steps = 62, loss = 0.0363 Cleared
# 809, steps = 32, loss = 0.0260 Cleared
# 810
# 811, steps = 22, loss = 0.0312 Cleared
# 813, steps = 16, loss = 0.0363 Cleared
# 814, steps = 49, loss = 0.0350 Cleared
# 815, steps = 48, loss = 0.0267 Cleared
# 816, steps = 53, loss = 0.0126 Cleared
# 817, steps = 78, loss = 0.0222 Cleared
# 818, steps = 31, loss = 0.0250 Cleared
# 819, steps = 59, loss = 0.0244 Cleared
# 820
# 824, steps = 24, loss = 0.0592 Cleared
# 825, steps = 36, loss = 0.0311 Cleared
# 826, steps = 9, loss = 0.0281 Cleared
# 827, steps = 30, loss = 0.0373 Cleared
# 829, steps = 21, loss = 0.0364 Cleared
# 830
# 830, steps = 21, loss = 0.0374 Cleared
# 832, steps = 34, loss = 0.0396 Cleared
# 833, steps = 66, loss = 0.0326 Cleared
# 835, steps = 7, loss = 0.0240 Cleared
# 836, steps = 64, loss = 0.0429 Cleared
# 837, steps = 76, loss = 0.0302 Cleared
# 838, steps = 18, loss = 0.0220 Cleared
# 839, steps = 21, loss = 0.0332 Cleared
# 840
# 841, steps = 40, loss = 0.0294 Cleared
# 843, steps = 7, loss = 0.0189 Cleared
# 844, steps = 13, loss = 0.0282 Cleared
# 846, steps = 60, loss = 0.0267 Cleared
# 848, steps = 52, loss = 0.0266 Cleared
# 850
# 851, steps = 29, loss = 0.0278 Cleared
# 852, steps = 27, loss = 0.0373 Cleared
# 853, steps = 14, loss = 0.0207 Cleared
# 854, steps = 33, loss = 0.0224 Cleared
# 855, steps = 44, loss = 0.0353 Cleared
# 856, steps = 11, loss = 0.0424 Cleared
# 857, steps = 26, loss = 0.0361 Cleared
# 858, steps = 33, loss = 0.0201 Cleared
# 860
# 860, steps = 51, loss = 0.0362 Cleared
# 862, steps = 29, loss = 0.0287 Cleared
# 863, steps = 17, loss = 0.0360 Cleared
# 864, steps = 18, loss = 0.0274 Cleared
# 865, steps = 13, loss = 0.0285 Cleared
# 866, steps = 20, loss = 0.0170 Cleared
# 868, steps = 21, loss = 0.0194 Cleared
# 870
# 872, steps = 16, loss = 0.0178 Cleared
# 873, steps = 18, loss = 0.0301 Cleared
# 874, steps = 45, loss = 0.0351 Cleared
# 875, steps = 27, loss = 0.0250 Cleared
# 876, steps = 24, loss = 0.0288 Cleared
# 877, steps = 63, loss = 0.0181 Cleared
# 879, steps = 23, loss = 0.0290 Cleared
# 880
# 881, steps = 44, loss = 0.0302 Cleared
# 884, steps = 23, loss = 0.0405 Cleared
# 885, steps = 27, loss = 0.0406 Cleared
# 886, steps = 99, loss = 0.0219 Cleared
# 888, steps = 9, loss = 0.0305 Cleared
# 889, steps = 7, loss = 0.0386 Cleared
# 890
# 890, steps = 60, loss = 0.0191 Cleared
# 891, steps = 27, loss = 0.0249 Cleared
# 892, steps = 68, loss = 0.0365 Cleared
# 893, steps = 32, loss = 0.0179 Cleared
# 895, steps = 28, loss = 0.0460 Cleared
# 896, steps = 25, loss = 0.0469 Cleared
# 897, steps = 16, loss = 0.0306 Cleared
# 900
# 900, steps = 13, loss = 0.0325 Cleared
# 901, steps = 29, loss = 0.0283 Cleared
# 903, steps = 66, loss = 0.0206 Cleared
# 904, steps = 30, loss = 0.0361 Cleared
# 905, steps = 78, loss = 0.0223 Cleared
# 906, steps = 49, loss = 0.0392 Cleared
# 907, steps = 24, loss = 0.0326 Cleared
# 908, steps = 12, loss = 0.0353 Cleared
# 909, steps = 52, loss = 0.0327 Cleared
# 910
# 911, steps = 32, loss = 0.0311 Cleared
# 912, steps = 13, loss = 0.0332 Cleared
# 913, steps = 97, loss = 0.0277 Cleared
# 914, steps = 26, loss = 0.0192 Cleared
# 915, steps = 35, loss = 0.0279 Cleared
# 917, steps = 96, loss = 0.0389 Cleared
# 918, steps = 45, loss = 0.0321 Cleared
# 919, steps = 20, loss = 0.0319 Cleared
# 920
# 922, steps = 7, loss = 0.0308 Cleared
# 923, steps = 23, loss = 0.0368 Cleared
# 924, steps = 15, loss = 0.0247 Cleared
# 926, steps = 45, loss = 0.0279 Cleared
# 927, steps = 26, loss = 0.0389 Cleared
# 928, steps = 40, loss = 0.0499 Cleared
# 929, steps = 35, loss = 0.0486 Cleared
# 930
# 930, steps = 12, loss = 0.0278 Cleared
# 931, steps = 9, loss = 0.0238 Cleared
# 932, steps = 69, loss = 0.0281 Cleared
# 935, steps = 27, loss = 0.0196 Cleared
# 936, steps = 34, loss = 0.0317 Cleared
# 937, steps = 51, loss = 0.0357 Cleared
# 939, steps = 59, loss = 0.0325 Cleared
# 940
# 940, steps = 74, loss = 0.0368 Cleared
# 941, steps = 37, loss = 0.0349 Cleared
# 942, steps = 54, loss = 0.0252 Cleared
# 943, steps = 85, loss = 0.0380 Cleared
# 944, steps = 8, loss = 0.0376 Cleared
# 949, steps = 90, loss = 0.0412 Cleared
# 950
# 950, steps = 26, loss = 0.0413 Cleared
# 951, steps = 85, loss = 0.0508 Cleared
# 954, steps = 40, loss = 0.0305 Cleared
# 956, steps = 53, loss = 0.0391 Cleared
# 957, steps = 34, loss = 0.0365 Cleared
# 958, steps = 38, loss = 0.0348 Cleared
# 959, steps = 43, loss = 0.0238 Cleared
# 960
# 960, steps = 32, loss = 0.0357 Cleared
# 961, steps = 9, loss = 0.0213 Cleared
# 962, steps = 65, loss = 0.0332 Cleared
# 964, steps = 18, loss = 0.0352 Cleared
# 965, steps = 71, loss = 0.0304 Cleared
# 968, steps = 24, loss = 0.0492 Cleared
# 969, steps = 11, loss = 0.0381 Cleared
# 970
# 970, steps = 46, loss = 0.0263 Cleared
# 971, steps = 71, loss = 0.0272 Cleared
# 972, steps = 29, loss = 0.0413 Cleared
# 973, steps = 17, loss = 0.0529 Cleared
# 974, steps = 18, loss = 0.0337 Cleared
# 975, steps = 25, loss = 0.0196 Cleared
# 976, steps = 84, loss = 0.0404 Cleared
# 978, steps = 23, loss = 0.0398 Cleared
# 979, steps = 19, loss = 0.0270 Cleared
# 980
# 980, steps = 30, loss = 0.0363 Cleared
# 981, steps = 14, loss = 0.0352 Cleared
# 982, steps = 19, loss = 0.0251 Cleared
# 984, steps = 10, loss = 0.0357 Cleared
# 985, steps = 30, loss = 0.0192 Cleared
# 986, steps = 22, loss = 0.0481 Cleared
# 988, steps = 34, loss = 0.0220 Cleared
# 989, steps = 41, loss = 0.0240 Cleared
# 990
# 990, steps = 19, loss = 0.0304 Cleared
# 991, steps = 11, loss = 0.0370 Cleared
# 992, steps = 29, loss = 0.0366 Cleared
# 993, steps = 26, loss = 0.0395 Cleared
# 994, steps = 66, loss = 0.0268 Cleared
# 995, steps = 31, loss = 0.0549 Cleared
# 997, steps = 31, loss = 0.0294 Cleared
# 998, steps = 51, loss = 0.0360 Cleared
# 999, steps = 23, loss = 0.0366 Cleared
# 1000
# 1000, steps = 8, loss = 0.0252 Cleared
# 1001, steps = 30, loss = 0.0365 Cleared
# 1005, steps = 34, loss = 0.0429 Cleared
# 1006, steps = 87, loss = 0.0327 Cleared
# 1008, steps = 26, loss = 0.0290 Cleared
# 1009, steps = 79, loss = 0.0341 Cleared
# 1010
# 1010, steps = 14, loss = 0.0303 Cleared
# 1011, steps = 89, loss = 0.0263 Cleared
# 1012, steps = 61, loss = 0.0316 Cleared
# 1014, steps = 82, loss = 0.0276 Cleared
# 1015, steps = 42, loss = 0.0266 Cleared
# 1016, steps = 10, loss = 0.0331 Cleared
# 1017, steps = 14, loss = 0.0375 Cleared
# 1018, steps = 60, loss = 0.0488 Cleared
# 1019, steps = 15, loss = 0.0333 Cleared
# 1020
# 1020, steps = 50, loss = 0.0326 Cleared
# 1021, steps = 25, loss = 0.0348 Cleared
# 1022, steps = 15, loss = 0.0301 Cleared
# 1023, steps = 91, loss = 0.0514 Cleared
# 1024, steps = 99, loss = 0.0312 Cleared
# 1026, steps = 19, loss = 0.0285 Cleared
# 1028, steps = 57, loss = 0.0405 Cleared
# 1029, steps = 7, loss = 0.0392 Cleared
# 1030
# 1030, steps = 34, loss = 0.0263 Cleared
# 1033, steps = 30, loss = 0.0227 Cleared
# 1034, steps = 48, loss = 0.0224 Cleared
# 1035, steps = 48, loss = 0.0516 Cleared
# 1037, steps = 30, loss = 0.0356 Cleared
# 1038, steps = 44, loss = 0.0293 Cleared
# 1039, steps = 70, loss = 0.0445 Cleared
# 1040
# 1041, steps = 25, loss = 0.0439 Cleared
# 1042, steps = 9, loss = 0.0204 Cleared
# 1043, steps = 28, loss = 0.0219 Cleared
# 1045, steps = 56, loss = 0.0529 Cleared
# 1046, steps = 10, loss = 0.0212 Cleared
# 1047, steps = 29, loss = 0.0307 Cleared
# 1048, steps = 76, loss = 0.0251 Cleared
# 1049, steps = 86, loss = 0.0224 Cleared
# 1050
# 1051, steps = 11, loss = 0.0273 Cleared
# 1052, steps = 23, loss = 0.0294 Cleared
# 1054, steps = 74, loss = 0.0328 Cleared
# 1055, steps = 55, loss = 0.0273 Cleared
# 1056, steps = 42, loss = 0.0287 Cleared
# 1057, steps = 44, loss = 0.0224 Cleared
# 1058, steps = 45, loss = 0.0325 Cleared
# 1059, steps = 17, loss = 0.0450 Cleared
# 1060
# 1060, steps = 45, loss = 0.0487 Cleared
# 1061, steps = 19, loss = 0.0442 Cleared
# 1062, steps = 12, loss = 0.0353 Cleared
# 1063, steps = 12, loss = 0.0244 Cleared
# 1064, steps = 29, loss = 0.0252 Cleared
# 1065, steps = 35, loss = 0.0314 Cleared
# 1066, steps = 26, loss = 0.0412 Cleared
# 1067, steps = 37, loss = 0.0343 Cleared
# 1070
# 1071, steps = 47, loss = 0.0341 Cleared
# 1072, steps = 22, loss = 0.0320 Cleared
# 1073, steps = 75, loss = 0.0271 Cleared
# 1074, steps = 19, loss = 0.0341 Cleared
# 1075, steps = 22, loss = 0.0390 Cleared
# 1077, steps = 35, loss = 0.0231 Cleared
# 1078, steps = 69, loss = 0.0235 Cleared
# 1079, steps = 37, loss = 0.0335 Cleared
# 1080
# 1080, steps = 22, loss = 0.0329 Cleared
# 1082, steps = 35, loss = 0.0561 Cleared
# 1086, steps = 9, loss = 0.0430 Cleared
# 1088, steps = 65, loss = 0.0380 Cleared
# 1089, steps = 83, loss = 0.0270 Cleared
# 1090
# 1090, steps = 62, loss = 0.0272 Cleared
# 1093, steps = 22, loss = 0.0554 Cleared
# 1095, steps = 70, loss = 0.0270 Cleared
# 1096, steps = 21, loss = 0.0374 Cleared
# 1097, steps = 33, loss = 0.0296 Cleared
# 1099, steps = 12, loss = 0.0287 Cleared
# 1100
# 1100, steps = 52, loss = 0.0322 Cleared
# 1101, steps = 22, loss = 0.0491 Cleared
# 1102, steps = 67, loss = 0.0350 Cleared
# 1103, steps = 10, loss = 0.0336 Cleared
# 1104, steps = 26, loss = 0.0253 Cleared
# 1105, steps = 10, loss = 0.0335 Cleared
# 1106, steps = 63, loss = 0.0321 Cleared
# 1108, steps = 34, loss = 0.0301 Cleared
# 1109, steps = 28, loss = 0.0254 Cleared
# 1110
# 1110, steps = 73, loss = 0.0247 Cleared
# 1111, steps = 24, loss = 0.0278 Cleared
# 1112, steps = 40, loss = 0.0325 Cleared
# 1113, steps = 19, loss = 0.0361 Cleared
# 1114, steps = 32, loss = 0.0216 Cleared
# 1115, steps = 85, loss = 0.0268 Cleared
# 1116, steps = 8, loss = 0.0431 Cleared
# 1117, steps = 9, loss = 0.0365 Cleared
# 1118, steps = 25, loss = 0.0254 Cleared
# 1119, steps = 20, loss = 0.0322 Cleared
# 1120
# 1120, steps = 17, loss = 0.0264 Cleared
# 1121, steps = 86, loss = 0.0372 Cleared
# 1122, steps = 71, loss = 0.0341 Cleared
# 1124, steps = 27, loss = 0.0601 Cleared
# 1125, steps = 36, loss = 0.0363 Cleared
# 1126, steps = 31, loss = 0.0242 Cleared
# 1128, steps = 14, loss = 0.0204 Cleared
# 1129, steps = 57, loss = 0.0407 Cleared
# 1130
# 1130, steps = 48, loss = 0.0333 Cleared
# 1131, steps = 46, loss = 0.0344 Cleared
# 1132, steps = 64, loss = 0.0407 Cleared
# 1133, steps = 35, loss = 0.0400 Cleared
# 1134, steps = 16, loss = 0.0278 Cleared
# 1135, steps = 52, loss = 0.0456 Cleared
# 1136, steps = 13, loss = 0.0400 Cleared
# 1137, steps = 59, loss = 0.0241 Cleared
# 1138, steps = 38, loss = 0.0267 Cleared
# 1139, steps = 42, loss = 0.0261 Cleared
# 1140
# 1140, steps = 47, loss = 0.0321 Cleared
# 1141, steps = 84, loss = 0.0296 Cleared
# 1142, steps = 11, loss = 0.0406 Cleared
# 1143, steps = 14, loss = 0.0305 Cleared
# 1144, steps = 12, loss = 0.0335 Cleared
# 1145, steps = 33, loss = 0.0380 Cleared
# 1146, steps = 13, loss = 0.0274 Cleared
# 1150
# 1151, steps = 18, loss = 0.0370 Cleared
# 1154, steps = 48, loss = 0.0394 Cleared
# 1155, steps = 14, loss = 0.0267 Cleared
# 1156, steps = 38, loss = 0.0364 Cleared
# 1158, steps = 78, loss = 0.0260 Cleared
# 1160
# 1160, steps = 93, loss = 0.0370 Cleared
# 1161, steps = 46, loss = 0.0369 Cleared
# 1162, steps = 100, loss = 0.0197 Cleared
# 1164, steps = 39, loss = 0.0265 Cleared
# 1165, steps = 64, loss = 0.0292 Cleared
# 1168, steps = 71, loss = 0.0396 Cleared
# 1169, steps = 43, loss = 0.0313 Cleared
# 1170
# 1170, steps = 39, loss = 0.0290 Cleared
# 1172, steps = 13, loss = 0.0346 Cleared
# 1173, steps = 54, loss = 0.0300 Cleared
# 1174, steps = 93, loss = 0.0220 Cleared
# 1176, steps = 75, loss = 0.0407 Cleared
# 1177, steps = 50, loss = 0.0368 Cleared
# 1179, steps = 73, loss = 0.0350 Cleared
# 1180
# 1182, steps = 82, loss = 0.0534 Cleared
# 1183, steps = 19, loss = 0.0402 Cleared
# 1185, steps = 16, loss = 0.0319 Cleared
# 1187, steps = 31, loss = 0.0301 Cleared
# 1188, steps = 70, loss = 0.0319 Cleared
# 1189, steps = 35, loss = 0.0256 Cleared
# 1190
# 1191, steps = 20, loss = 0.0150 Cleared
# 1193, steps = 46, loss = 0.0169 Cleared
# 1196, steps = 32, loss = 0.0590 Cleared
# 1198, steps = 33, loss = 0.0323 Cleared
# 1199, steps = 73, loss = 0.0253 Cleared
# 1200
# 1200, steps = 54, loss = 0.0336 Cleared
# 1201, steps = 53, loss = 0.0460 Cleared
# 1204, steps = 52, loss = 0.0466 Cleared
# 1205, steps = 55, loss = 0.0268 Cleared
# 1206, steps = 91, loss = 0.0343 Cleared
# 1207, steps = 33, loss = 0.0196 Cleared
# 1209, steps = 22, loss = 0.0175 Cleared
# 1210
# 1210, steps = 24, loss = 0.0374 Cleared
# 1212, steps = 76, loss = 0.0391 Cleared
# 1213, steps = 14, loss = 0.0323 Cleared
# 1215, steps = 30, loss = 0.0284 Cleared
# 1216, steps = 66, loss = 0.0365 Cleared
# 1218, steps = 69, loss = 0.0273 Cleared
# 1220
# 1220, steps = 79, loss = 0.0330 Cleared
# 1222, steps = 33, loss = 0.0366 Cleared
# 1223, steps = 46, loss = 0.0447 Cleared
# 1226, steps = 82, loss = 0.0422 Cleared
# 1228, steps = 41, loss = 0.0247 Cleared
# 1229, steps = 48, loss = 0.0412 Cleared
# 1230
# 1230, steps = 28, loss = 0.0357 Cleared
# 1231, steps = 16, loss = 0.0295 Cleared
# 1232, steps = 8, loss = 0.0232 Cleared
# 1233, steps = 63, loss = 0.0264 Cleared
# 1234, steps = 19, loss = 0.0439 Cleared
# 1237, steps = 76, loss = 0.0292 Cleared
# 1239, steps = 13, loss = 0.0232 Cleared
# 1240
# 1240, steps = 13, loss = 0.0332 Cleared
# 1241, steps = 75, loss = 0.0350 Cleared
# 1244, steps = 36, loss = 0.0300 Cleared
# 1245, steps = 17, loss = 0.0363 Cleared
# 1246, steps = 18, loss = 0.0368 Cleared
# 1248, steps = 17, loss = 0.0249 Cleared
# 1250
# 1250, steps = 56, loss = 0.0336 Cleared
# 1252, steps = 27, loss = 0.0240 Cleared
# 1255, steps = 16, loss = 0.0329 Cleared
# 1256, steps = 86, loss = 0.0318 Cleared
# 1257, steps = 64, loss = 0.0271 Cleared
# 1258, steps = 37, loss = 0.0175 Cleared
# 1260
# 1260, steps = 56, loss = 0.0326 Cleared
# 1261, steps = 21, loss = 0.0545 Cleared
# 1264, steps = 21, loss = 0.0319 Cleared
# 1265, steps = 66, loss = 0.0363 Cleared
# 1266, steps = 57, loss = 0.0346 Cleared
# 1268, steps = 86, loss = 0.0367 Cleared
# 1269, steps = 40, loss = 0.0296 Cleared
# 1270
# 1273, steps = 67, loss = 0.0362 Cleared
# 1274, steps = 27, loss = 0.0321 Cleared
# 1276, steps = 18, loss = 0.0358 Cleared
# 1277, steps = 26, loss = 0.0326 Cleared
# 1279, steps = 13, loss = 0.0323 Cleared
# 1280
# 1280, steps = 91, loss = 0.0238 Cleared
# 1281, steps = 29, loss = 0.0247 Cleared
# 1282, steps = 25, loss = 0.0350 Cleared
# 1283, steps = 11, loss = 0.0347 Cleared
# 1284, steps = 9, loss = 0.0436 Cleared
# 1285, steps = 64, loss = 0.0328 Cleared
# 1287, steps = 61, loss = 0.0321 Cleared
# 1288, steps = 14, loss = 0.0312 Cleared
# 1289, steps = 49, loss = 0.0323 Cleared
# 1290
# 1290, steps = 33, loss = 0.0273 Cleared
# 1291, steps = 19, loss = 0.0273 Cleared
# 1293, steps = 95, loss = 0.0261 Cleared
# 1294, steps = 75, loss = 0.0405 Cleared
# 1295, steps = 28, loss = 0.0355 Cleared
# 1297, steps = 25, loss = 0.0332 Cleared
# 1298, steps = 63, loss = 0.0251 Cleared
# 1300
# 1301, steps = 45, loss = 0.0217 Cleared
# 1302, steps = 59, loss = 0.0438 Cleared
# 1303, steps = 63, loss = 0.0351 Cleared
# 1306, steps = 6, loss = 0.0426 Cleared
# 1307, steps = 30, loss = 0.0328 Cleared
# 1309, steps = 16, loss = 0.0266 Cleared
# 1310
# 1313, steps = 16, loss = 0.0373 Cleared
# 1315, steps = 46, loss = 0.0242 Cleared
# 1316, steps = 84, loss = 0.0277 Cleared
# 1317, steps = 18, loss = 0.0264 Cleared
# 1318, steps = 35, loss = 0.0336 Cleared
# 1319, steps = 59, loss = 0.0291 Cleared
# 1320
# 1320, steps = 25, loss = 0.0384 Cleared
# 1321, steps = 13, loss = 0.0329 Cleared
# 1322, steps = 54, loss = 0.0252 Cleared
# 1324, steps = 39, loss = 0.0515 Cleared
# 1326, steps = 81, loss = 0.0324 Cleared
# 1328, steps = 64, loss = 0.0248 Cleared
# 1329, steps = 38, loss = 0.0223 Cleared
# 1330
# 1330, steps = 90, loss = 0.0337 Cleared
# 1332, steps = 34, loss = 0.0311 Cleared
# 1333, steps = 12, loss = 0.0251 Cleared
# 1335, steps = 30, loss = 0.0270 Cleared
# 1336, steps = 81, loss = 0.0314 Cleared
# 1337, steps = 57, loss = 0.0228 Cleared
# 1338, steps = 38, loss = 0.0374 Cleared
# 1340
# 1340, steps = 12, loss = 0.0415 Cleared
# 1342, steps = 13, loss = 0.0333 Cleared
# 1343, steps = 23, loss = 0.0426 Cleared
# 1345, steps = 51, loss = 0.0344 Cleared
# 1346, steps = 24, loss = 0.0294 Cleared
# 1349, steps = 41, loss = 0.0390 Cleared
# 1350
# 1350, steps = 27, loss = 0.0362 Cleared
# 1351, steps = 78, loss = 0.0322 Cleared
# 1352, steps = 16, loss = 0.0340 Cleared
# 1353, steps = 16, loss = 0.0203 Cleared
# 1354, steps = 34, loss = 0.0396 Cleared
# 1356, steps = 22, loss = 0.0321 Cleared
# 1357, steps = 7, loss = 0.0415 Cleared
# 1358, steps = 33, loss = 0.0294 Cleared
# 1360
# 1360, steps = 45, loss = 0.0273 Cleared
# 1361, steps = 26, loss = 0.0365 Cleared
# 1362, steps = 16, loss = 0.0295 Cleared
# 1363, steps = 28, loss = 0.0326 Cleared
# 1364, steps = 31, loss = 0.0324 Cleared
# 1366, steps = 25, loss = 0.0416 Cleared
# 1367, steps = 16, loss = 0.0240 Cleared
# 1368, steps = 37, loss = 0.0451 Cleared
# 1370
# 1372, steps = 18, loss = 0.0433 Cleared
# 1374, steps = 77, loss = 0.0308 Cleared
# 1375, steps = 33, loss = 0.0348 Cleared
# 1376, steps = 20, loss = 0.0246 Cleared
# 1380
# 1381, steps = 35, loss = 0.0314 Cleared
# 1382, steps = 50, loss = 0.0462 Cleared
# 1384, steps = 22, loss = 0.0293 Cleared
# 1388, steps = 36, loss = 0.0210 Cleared
# 1390
# 1392, steps = 17, loss = 0.0175 Cleared
# 1394, steps = 38, loss = 0.0289 Cleared
# 1395, steps = 49, loss = 0.0282 Cleared
# 1400
# 1400, steps = 16, loss = 0.0257 Cleared
# 1402, steps = 31, loss = 0.0353 Cleared
# 1403, steps = 15, loss = 0.0295 Cleared
# 1404, steps = 18, loss = 0.0245 Cleared
# 1405, steps = 62, loss = 0.0260 Cleared
# 1406, steps = 50, loss = 0.0345 Cleared
# 1408, steps = 30, loss = 0.0474 Cleared
# 1409, steps = 67, loss = 0.0382 Cleared
# 1410
# 1410, steps = 11, loss = 0.0235 Cleared
# 1413, steps = 28, loss = 0.0329 Cleared
# 1414, steps = 96, loss = 0.0370 Cleared
# 1416, steps = 28, loss = 0.0394 Cleared
# 1419, steps = 49, loss = 0.0377 Cleared
# 1420
# 1421, steps = 24, loss = 0.0274 Cleared
# 1422, steps = 27, loss = 0.0217 Cleared
# 1423, steps = 22, loss = 0.0285 Cleared
# 1424, steps = 34, loss = 0.0186 Cleared
# 1425, steps = 89, loss = 0.0281 Cleared
# 1427, steps = 13, loss = 0.0541 Cleared
# 1428, steps = 15, loss = 0.0308 Cleared
# 1430
# 1430, steps = 56, loss = 0.0374 Cleared
# 1431, steps = 30, loss = 0.0289 Cleared
# 1432, steps = 95, loss = 0.0272 Cleared
# 1433, steps = 40, loss = 0.0400 Cleared
# 1434, steps = 56, loss = 0.0286 Cleared
# 1437, steps = 29, loss = 0.0262 Cleared
# 1440
# 1440, steps = 38, loss = 0.0308 Cleared
# 1441, steps = 21, loss = 0.0342 Cleared
# 1444, steps = 66, loss = 0.0321 Cleared
# 1446, steps = 25, loss = 0.0290 Cleared
# 1449, steps = 72, loss = 0.0199 Cleared
# 1450
# 1450, steps = 27, loss = 0.0457 Cleared
# 1452, steps = 52, loss = 0.0354 Cleared
# 1454, steps = 32, loss = 0.0232 Cleared
# 1456, steps = 22, loss = 0.0425 Cleared
# 1457, steps = 63, loss = 0.0330 Cleared
# 1460
# 1463, steps = 19, loss = 0.0396 Cleared
# 1464, steps = 21, loss = 0.0417 Cleared
# 1465, steps = 6, loss = 0.0263 Cleared
# 1468, steps = 35, loss = 0.0315 Cleared
# 1469, steps = 23, loss = 0.0320 Cleared
# 1470
# 1470, steps = 80, loss = 0.0265 Cleared
# 1473, steps = 10, loss = 0.0398 Cleared
# 1474, steps = 16, loss = 0.0290 Cleared
# 1475, steps = 24, loss = 0.0305 Cleared
# 1476, steps = 80, loss = 0.0348 Cleared
# 1477, steps = 13, loss = 0.0223 Cleared
# 1479, steps = 39, loss = 0.0311 Cleared
# 1480
# 1480, steps = 50, loss = 0.0312 Cleared
# 1481, steps = 84, loss = 0.0205 Cleared
# 1483, steps = 37, loss = 0.0206 Cleared
# 1484, steps = 14, loss = 0.0267 Cleared
# 1485, steps = 42, loss = 0.0494 Cleared
# 1487, steps = 11, loss = 0.0247 Cleared
# 1488, steps = 9, loss = 0.0482 Cleared
# 1490
# 1491, steps = 41, loss = 0.0301 Cleared
# 1492, steps = 23, loss = 0.0478 Cleared
# 1493, steps = 27, loss = 0.0358 Cleared
# 1494, steps = 8, loss = 0.0421 Cleared
# 1497, steps = 14, loss = 0.0270 Cleared
# 1499, steps = 29, loss = 0.0305 Cleared
# 1500
# 1501, steps = 30, loss = 0.0358 Cleared
# 1503, steps = 77, loss = 0.0313 Cleared
# 1504, steps = 50, loss = 0.0304 Cleared
# 1506, steps = 27, loss = 0.0260 Cleared
# 1507, steps = 17, loss = 0.0421 Cleared
# 1509, steps = 45, loss = 0.0403 Cleared
# 1510
# 1510, steps = 86, loss = 0.0338 Cleared
# 1511, steps = 91, loss = 0.0302 Cleared
# 1512, steps = 40, loss = 0.0216 Cleared
# 1514, steps = 15, loss = 0.0328 Cleared
# 1517, steps = 27, loss = 0.0437 Cleared
# 1518, steps = 21, loss = 0.0389 Cleared
# 1520
# 1520, steps = 42, loss = 0.0161 Cleared
# 1521, steps = 24, loss = 0.0207 Cleared
# 1522, steps = 13, loss = 0.0332 Cleared
# 1524, steps = 17, loss = 0.0332 Cleared
# 1526, steps = 22, loss = 0.0301 Cleared
# 1528, steps = 37, loss = 0.0222 Cleared
# 1530
# 1530, steps = 15, loss = 0.0467 Cleared
# 1531, steps = 27, loss = 0.0285 Cleared
# 1533, steps = 20, loss = 0.0443 Cleared
# 1534, steps = 26, loss = 0.0421 Cleared
# 1535, steps = 34, loss = 0.0509 Cleared
# 1537, steps = 92, loss = 0.0343 Cleared
# 1538, steps = 15, loss = 0.0464 Cleared
# 1539, steps = 38, loss = 0.0379 Cleared
# 1540
# 1541, steps = 40, loss = 0.0334 Cleared
# 1542, steps = 26, loss = 0.0221 Cleared
# 1543, steps = 13, loss = 0.0334 Cleared
# 1545, steps = 16, loss = 0.0209 Cleared
# 1546, steps = 21, loss = 0.0377 Cleared
# 1547, steps = 48, loss = 0.0328 Cleared
# 1549, steps = 47, loss = 0.0292 Cleared
# 1550
# 1550, steps = 62, loss = 0.0281 Cleared
# 1551, steps = 29, loss = 0.0186 Cleared
# 1553, steps = 6, loss = 0.0389 Cleared
# 1554, steps = 85, loss = 0.0508 Cleared
# 1555, steps = 80, loss = 0.0210 Cleared
# 1556, steps = 14, loss = 0.0377 Cleared
# 1558, steps = 89, loss = 0.0404 Cleared
# 1560
# 1561, steps = 16, loss = 0.0251 Cleared
# 1565, steps = 25, loss = 0.0364 Cleared
# 1568, steps = 8, loss = 0.0579 Cleared
# 1569, steps = 26, loss = 0.0372 Cleared
# 1570
# 1570, steps = 26, loss = 0.0275 Cleared
# 1571, steps = 88, loss = 0.0312 Cleared
# 1572, steps = 41, loss = 0.0334 Cleared
# 1573, steps = 10, loss = 0.0286 Cleared
# 1574, steps = 48, loss = 0.0178 Cleared
# 1575, steps = 53, loss = 0.0345 Cleared
# 1577, steps = 19, loss = 0.0189 Cleared
# 1579, steps = 22, loss = 0.0343 Cleared
# 1580
# 1580, steps = 8, loss = 0.0421 Cleared
# 1581, steps = 14, loss = 0.0374 Cleared
# 1582, steps = 91, loss = 0.0197 Cleared
# 1583, steps = 14, loss = 0.0423 Cleared
# 1584, steps = 30, loss = 0.0485 Cleared
# 1585, steps = 17, loss = 0.0226 Cleared
# 1586, steps = 75, loss = 0.0280 Cleared
# 1587, steps = 21, loss = 0.0384 Cleared
# 1588, steps = 25, loss = 0.0405 Cleared
# 1590
# 1590, steps = 14, loss = 0.0361 Cleared
# 1591, steps = 13, loss = 0.0234 Cleared
# 1593, steps = 26, loss = 0.0468 Cleared
# 1594, steps = 18, loss = 0.0300 Cleared
# 1595, steps = 28, loss = 0.0259 Cleared
# 1596, steps = 14, loss = 0.0281 Cleared
# 1597, steps = 30, loss = 0.0276 Cleared
# 1598, steps = 21, loss = 0.0267 Cleared
# 1600
# 1601, steps = 54, loss = 0.0378 Cleared
# 1602, steps = 53, loss = 0.0319 Cleared
# 1603, steps = 49, loss = 0.0202 Cleared
# 1605, steps = 88, loss = 0.0233 Cleared
# 1607, steps = 24, loss = 0.0305 Cleared
# 1610
# 1610, steps = 45, loss = 0.0515 Cleared
# 1613, steps = 22, loss = 0.0302 Cleared
# 1614, steps = 23, loss = 0.0238 Cleared
# 1615, steps = 46, loss = 0.0394 Cleared
# 1616, steps = 41, loss = 0.0302 Cleared
# 1617, steps = 28, loss = 0.0296 Cleared
# 1618, steps = 26, loss = 0.0163 Cleared
# 1620
# 1620, steps = 27, loss = 0.0206 Cleared
# 1621, steps = 20, loss = 0.0406 Cleared
# 1622, steps = 76, loss = 0.0286 Cleared
# 1624, steps = 25, loss = 0.0307 Cleared
# 1625, steps = 26, loss = 0.0282 Cleared
# 1627, steps = 9, loss = 0.0316 Cleared
# 1630
# 1632, steps = 19, loss = 0.0394 Cleared
# 1633, steps = 13, loss = 0.0368 Cleared
# 1635, steps = 18, loss = 0.0175 Cleared
# 1636, steps = 22, loss = 0.0347 Cleared
# 1638, steps = 54, loss = 0.0273 Cleared
# 1639, steps = 49, loss = 0.0298 Cleared
# 1640
# 1640, steps = 27, loss = 0.0382 Cleared
# 1641, steps = 20, loss = 0.0303 Cleared
# 1642, steps = 23, loss = 0.0209 Cleared
# 1643, steps = 74, loss = 0.0252 Cleared
# 1645, steps = 12, loss = 0.0350 Cleared
# 1647, steps = 72, loss = 0.0561 Cleared
# 1648, steps = 51, loss = 0.0421 Cleared
# 1649, steps = 54, loss = 0.0449 Cleared
# 1650
# 1652, steps = 15, loss = 0.0249 Cleared
# 1654, steps = 79, loss = 0.0280 Cleared
# 1655, steps = 27, loss = 0.0288 Cleared
# 1656, steps = 34, loss = 0.0256 Cleared
# 1657, steps = 9, loss = 0.0353 Cleared
# 1658, steps = 76, loss = 0.0262 Cleared
# 1659, steps = 46, loss = 0.0158 Cleared
# 1660
# 1660, steps = 45, loss = 0.0159 Cleared
# 1661, steps = 27, loss = 0.0328 Cleared
# 1662, steps = 43, loss = 0.0232 Cleared
# 1663, steps = 35, loss = 0.0349 Cleared
# 1665, steps = 87, loss = 0.0281 Cleared
# 1666, steps = 91, loss = 0.0202 Cleared
# 1667, steps = 99, loss = 0.0347 Cleared
# 1669, steps = 57, loss = 0.0348 Cleared
# 1670
# 1670, steps = 34, loss = 0.0385 Cleared
# 1671, steps = 26, loss = 0.0383 Cleared
# 1672, steps = 16, loss = 0.0294 Cleared
# 1673, steps = 74, loss = 0.0242 Cleared
# 1675, steps = 54, loss = 0.0352 Cleared
# 1676, steps = 28, loss = 0.0291 Cleared
# 1677, steps = 36, loss = 0.0377 Cleared
# 1680
# 1680, steps = 22, loss = 0.0236 Cleared
# 1681, steps = 21, loss = 0.0463 Cleared
# 1682, steps = 46, loss = 0.0245 Cleared
# 1683, steps = 41, loss = 0.0233 Cleared
# 1684, steps = 79, loss = 0.0278 Cleared
# 1686, steps = 10, loss = 0.0278 Cleared
# 1688, steps = 20, loss = 0.0505 Cleared
# 1689, steps = 74, loss = 0.0327 Cleared
# 1690
# 1692, steps = 85, loss = 0.0161 Cleared
# 1694, steps = 64, loss = 0.0424 Cleared
# 1695, steps = 14, loss = 0.0385 Cleared
# 1697, steps = 16, loss = 0.0310 Cleared
# 1699, steps = 49, loss = 0.0210 Cleared
# 1700
# 1700, steps = 52, loss = 0.0317 Cleared
# 1701, steps = 27, loss = 0.0212 Cleared
# 1702, steps = 71, loss = 0.0433 Cleared
# 1703, steps = 31, loss = 0.0248 Cleared
# 1704, steps = 21, loss = 0.0330 Cleared
# 1705, steps = 34, loss = 0.0367 Cleared
# 1706, steps = 54, loss = 0.0415 Cleared
# 1707, steps = 24, loss = 0.0204 Cleared
# 1709, steps = 22, loss = 0.0324 Cleared
# 1710
# 1711, steps = 23, loss = 0.0299 Cleared
# 1712, steps = 51, loss = 0.0242 Cleared
# 1713, steps = 41, loss = 0.0319 Cleared
# 1716, steps = 69, loss = 0.0280 Cleared
# 1719, steps = 27, loss = 0.0424 Cleared
# 1720
# 1721, steps = 99, loss = 0.0294 Cleared
# 1722, steps = 9, loss = 0.0264 Cleared
# 1724, steps = 8, loss = 0.0451 Cleared
# 1728, steps = 15, loss = 0.0217 Cleared
# 1729, steps = 28, loss = 0.0257 Cleared
# 1730
# 1732, steps = 35, loss = 0.0195 Cleared
# 1733, steps = 13, loss = 0.0280 Cleared
# 1734, steps = 16, loss = 0.0280 Cleared
# 1735, steps = 9, loss = 0.0308 Cleared
# 1737, steps = 39, loss = 0.0352 Cleared
# 1738, steps = 15, loss = 0.0287 Cleared
# 1739, steps = 52, loss = 0.0253 Cleared
# 1740
# 1740, steps = 14, loss = 0.0231 Cleared
# 1741, steps = 20, loss = 0.0400 Cleared
# 1742, steps = 25, loss = 0.0330 Cleared
# 1745, steps = 20, loss = 0.0410 Cleared
# 1747, steps = 36, loss = 0.0357 Cleared
# 1749, steps = 91, loss = 0.0313 Cleared
# 1750
# 1750, steps = 84, loss = 0.0341 Cleared
# 1751, steps = 74, loss = 0.0187 Cleared
# 1752, steps = 11, loss = 0.0304 Cleared
# 1754, steps = 15, loss = 0.0198 Cleared
# 1755, steps = 44, loss = 0.0361 Cleared
# 1757, steps = 13, loss = 0.0284 Cleared
# 1758, steps = 27, loss = 0.0416 Cleared
# 1759, steps = 73, loss = 0.0459 Cleared
# 1760
# 1760, steps = 52, loss = 0.0364 Cleared
# 1763, steps = 40, loss = 0.0380 Cleared
# 1764, steps = 53, loss = 0.0386 Cleared
# 1767, steps = 56, loss = 0.0358 Cleared
# 1769, steps = 24, loss = 0.0243 Cleared
# 1770
# 1770, steps = 47, loss = 0.0561 Cleared
# 1771, steps = 14, loss = 0.0264 Cleared
# 1775, steps = 16, loss = 0.0310 Cleared
# 1776, steps = 23, loss = 0.0361 Cleared
# 1777, steps = 38, loss = 0.0341 Cleared
# 1778, steps = 66, loss = 0.0386 Cleared
# 1780
# 1780, steps = 42, loss = 0.0336 Cleared
# 1781, steps = 32, loss = 0.0284 Cleared
# 1782, steps = 35, loss = 0.0185 Cleared
# 1783, steps = 9, loss = 0.0456 Cleared
# 1785, steps = 54, loss = 0.0333 Cleared
# 1786, steps = 46, loss = 0.0302 Cleared
# 1787, steps = 24, loss = 0.0289 Cleared
# 1788, steps = 16, loss = 0.0338 Cleared
# 1790
# 1790, steps = 13, loss = 0.0432 Cleared
# 1791, steps = 63, loss = 0.0428 Cleared
# 1793, steps = 62, loss = 0.0254 Cleared
# 1794, steps = 20, loss = 0.0393 Cleared
# 1796, steps = 30, loss = 0.0320 Cleared
# 1797, steps = 19, loss = 0.0336 Cleared
# 1799, steps = 30, loss = 0.0383 Cleared
# 1800
# 1800, steps = 48, loss = 0.0418 Cleared
# 1804, steps = 16, loss = 0.0255 Cleared
# 1805, steps = 55, loss = 0.0339 Cleared
# 1806, steps = 12, loss = 0.0364 Cleared
# 1808, steps = 46, loss = 0.0342 Cleared
# 1809, steps = 43, loss = 0.0298 Cleared
# 1810
# 1810, steps = 44, loss = 0.0285 Cleared
# 1812, steps = 18, loss = 0.0486 Cleared
# 1813, steps = 27, loss = 0.0325 Cleared
# 1814, steps = 31, loss = 0.0274 Cleared
# 1816, steps = 72, loss = 0.0299 Cleared
# 1817, steps = 31, loss = 0.0300 Cleared
# 1818, steps = 70, loss = 0.0441 Cleared
# 1819, steps = 33, loss = 0.0308 Cleared
# 1820
# 1820, steps = 95, loss = 0.0320 Cleared
# 1821, steps = 30, loss = 0.0297 Cleared
# 1824, steps = 14, loss = 0.0401 Cleared
# 1825, steps = 62, loss = 0.0347 Cleared
# 1828, steps = 72, loss = 0.0240 Cleared
# 1829, steps = 22, loss = 0.0332 Cleared
# 1830
# 1830, steps = 39, loss = 0.0364 Cleared
# 1832, steps = 17, loss = 0.0226 Cleared
# 1833, steps = 22, loss = 0.0323 Cleared
# 1836, steps = 13, loss = 0.0376 Cleared
# 1839, steps = 35, loss = 0.0321 Cleared
# 1840
# 1840, steps = 38, loss = 0.0319 Cleared
# 1841, steps = 36, loss = 0.0273 Cleared
# 1843, steps = 49, loss = 0.0338 Cleared
# 1845, steps = 15, loss = 0.0256 Cleared
# 1846, steps = 71, loss = 0.0374 Cleared
# 1847, steps = 43, loss = 0.0355 Cleared
# 1848, steps = 11, loss = 0.0325 Cleared
# 1849, steps = 64, loss = 0.0327 Cleared
# 1850
# 1850, steps = 18, loss = 0.0403 Cleared
# 1852, steps = 29, loss = 0.0210 Cleared
# 1853, steps = 33, loss = 0.0368 Cleared
# 1855, steps = 20, loss = 0.0280 Cleared
# 1856, steps = 65, loss = 0.0417 Cleared
# 1858, steps = 42, loss = 0.0256 Cleared
# 1860
# 1860, steps = 29, loss = 0.0433 Cleared
# 1864, steps = 23, loss = 0.0230 Cleared
# 1865, steps = 67, loss = 0.0306 Cleared
# 1866, steps = 17, loss = 0.0261 Cleared
# 1867, steps = 16, loss = 0.0298 Cleared
# 1869, steps = 25, loss = 0.0341 Cleared
# 1870
# 1870, steps = 47, loss = 0.0317 Cleared
# 1871, steps = 65, loss = 0.0448 Cleared
# 1875, steps = 29, loss = 0.0326 Cleared
# 1877, steps = 10, loss = 0.0463 Cleared
# 1878, steps = 24, loss = 0.0471 Cleared
# 1879, steps = 30, loss = 0.0410 Cleared
# 1880
# 1881, steps = 20, loss = 0.0194 Cleared
# 1882, steps = 10, loss = 0.0293 Cleared
# 1884, steps = 59, loss = 0.0300 Cleared
# 1885, steps = 28, loss = 0.0214 Cleared
# 1886, steps = 16, loss = 0.0348 Cleared
# 1887, steps = 55, loss = 0.0365 Cleared
# 1888, steps = 90, loss = 0.0214 Cleared
# 1889, steps = 14, loss = 0.0273 Cleared
# 1890
# 1890, steps = 81, loss = 0.0253 Cleared
# 1892, steps = 17, loss = 0.0278 Cleared
# 1893, steps = 25, loss = 0.0429 Cleared
# 1894, steps = 78, loss = 0.0445 Cleared
# 1896, steps = 80, loss = 0.0214 Cleared
# 1897, steps = 35, loss = 0.0275 Cleared
# 1898, steps = 33, loss = 0.0482 Cleared
# 1899, steps = 49, loss = 0.0389 Cleared
# 1900
# 1900, steps = 33, loss = 0.0377 Cleared
# 1902, steps = 33, loss = 0.0410 Cleared
# 1905, steps = 12, loss = 0.0354 Cleared
# 1906, steps = 65, loss = 0.0419 Cleared
# 1908, steps = 90, loss = 0.0349 Cleared
# 1909, steps = 23, loss = 0.0250 Cleared
# 1910
# 1910, steps = 81, loss = 0.0246 Cleared
# 1911, steps = 27, loss = 0.0293 Cleared
# 1912, steps = 22, loss = 0.0242 Cleared
# 1913, steps = 44, loss = 0.0440 Cleared
# 1914, steps = 65, loss = 0.0340 Cleared
# 1916, steps = 13, loss = 0.0257 Cleared
# 1918, steps = 17, loss = 0.0295 Cleared
# 1919, steps = 36, loss = 0.0275 Cleared
# 1920
# 1920, steps = 13, loss = 0.0276 Cleared
# 1921, steps = 83, loss = 0.0370 Cleared
# 1922, steps = 34, loss = 0.0368 Cleared
# 1924, steps = 25, loss = 0.0186 Cleared
# 1925, steps = 36, loss = 0.0264 Cleared
# 1927, steps = 42, loss = 0.0432 Cleared
# 1928, steps = 88, loss = 0.0314 Cleared
# 1929, steps = 17, loss = 0.0284 Cleared
# 1930
# 1930, steps = 24, loss = 0.0383 Cleared
# 1931, steps = 37, loss = 0.0249 Cleared
# 1932, steps = 54, loss = 0.0376 Cleared
# 1933, steps = 16, loss = 0.0344 Cleared
# 1935, steps = 28, loss = 0.0242 Cleared
# 1936, steps = 49, loss = 0.0269 Cleared
# 1938, steps = 34, loss = 0.0300 Cleared
# 1939, steps = 64, loss = 0.0340 Cleared
# 1940
# 1940, steps = 78, loss = 0.0462 Cleared
# 1941, steps = 37, loss = 0.0194 Cleared
# 1943, steps = 22, loss = 0.0378 Cleared
# 1945, steps = 19, loss = 0.0244 Cleared
# 1946, steps = 11, loss = 0.0173 Cleared
# 1950
# 1950, steps = 76, loss = 0.0280 Cleared
# 1952, steps = 27, loss = 0.0321 Cleared
# 1954, steps = 10, loss = 0.0285 Cleared
# 1958, steps = 39, loss = 0.0266 Cleared
# 1959, steps = 50, loss = 0.0328 Cleared
# 1960
# 1960, steps = 18, loss = 0.0431 Cleared
# 1962, steps = 42, loss = 0.0355 Cleared
# 1965, steps = 27, loss = 0.0281 Cleared
# 1966, steps = 32, loss = 0.0272 Cleared
# 1967, steps = 7, loss = 0.0262 Cleared
# 1968, steps = 27, loss = 0.0327 Cleared
# 1970
# 1972, steps = 54, loss = 0.0305 Cleared
# 1973, steps = 50, loss = 0.0464 Cleared
# 1974, steps = 19, loss = 0.0418 Cleared
# 1977, steps = 41, loss = 0.0333 Cleared
# 1979, steps = 37, loss = 0.0250 Cleared
# 1980
# 1983, steps = 22, loss = 0.0383 Cleared
# 1984, steps = 14, loss = 0.0379 Cleared
# 1986, steps = 35, loss = 0.0222 Cleared
# 1987, steps = 29, loss = 0.0253 Cleared
# 1988, steps = 33, loss = 0.0333 Cleared
# 1989, steps = 67, loss = 0.0376 Cleared
# 1990
# 1990, steps = 24, loss = 0.0255 Cleared
# 1991, steps = 72, loss = 0.0207 Cleared
# 1994, steps = 27, loss = 0.0270 Cleared
# 1996, steps = 83, loss = 0.0538 Cleared
# 1997, steps = 44, loss = 0.0364 Cleared
# 1998, steps = 20, loss = 0.0402 Cleared
# 1999, steps = 15, loss = 0.0311 Cleared

# %%
for i in range(16):
    with torch.no_grad():
        print(policyNet(getOneHotTensor(i,16)).max(1)[1])
# Out:
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([1])
# tensor([2])

# %%
for i in range(16):
    with torch.no_grad():
        print(targetNet(getOneHotTensor(i,16)).max(1)[1])
# Out:
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([1])
# tensor([0])

# %%
done_size
# Out:
# 1223
