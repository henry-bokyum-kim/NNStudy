# %%
import gym

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np

import random
import math

import collections
from collections import namedtuple

# %%
stepInfo = namedtuple('StepInfo',('cur_state', 'action','next_state', 'reward',))

class ReplayList():
    def __init__(self, size):
        self.memory = collections.deque(maxlen = size)
        
    def append(self, data):
        type(self.memory)
        self.memory.append(data)
        
    def sample(self, size):        
        if len(self.memory) < size:
            return None
        else:
            return random.sample(self.memory, size)
    
    def __len__(self):
        return len(self.memory)
    
    def __repr__(self):
        return print(self.memory)

# %%
class QNet(nn.Module):
    def __init__(self, in_size, hidden_size, out_size):
        super(QNet, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(in_size, hidden_size),
            nn.ReLU(),
#             nn.Linear(hidden_size, hidden_size),
#             nn.ReLU(),
            nn.Linear(hidden_size, out_size)
        )
        
    def forward(self,x):
        return self.net(x)

# %%
def getOneHotTensor(pos, size):
    ret = np.zeros((1,size))
    ret[0][pos] = 1
    return torch.FloatTensor(ret)#.cuda()

# %%
HIDDEN_SIZE = 128
LR = 0.0002
EPOCH = 2000

MEM_SIZE = 3000

GAMMA = 0.95
EPS_START = .9
EPS_END = 0.005
EPS_DECAY = 200

BATCH = 128
TARGET_UPDATE = 10

env = gym.make("FrozenLake-v0")

policyNet = QNet(env.observation_space.n, HIDDEN_SIZE, env.action_space.n)#.cuda()
targetNet = QNet(env.observation_space.n, HIDDEN_SIZE, env.action_space.n)#.cuda()
targetNet.load_state_dict(policyNet.state_dict())
targetNet.eval()

memory = ReplayList(MEM_SIZE)

done_size = 0

optimizer = optim.Adam(policyNet.parameters(), lr = LR)
loss = nn.MSELoss(reduction="sum")

# %%
if __name__ == "__main__":
    obs = env.reset()
    loss_list = []
    step_count = 0
    cur_target = 0
    target_list = []
    for i in range(EPOCH):
        if i%TARGET_UPDATE == 0:
            if cur_target/TARGET_UPDATE >= 0.5:
                target_list.append((i,cur_target,targetNet.state_dict()))
            else:
                targetNet.load_state_dict(policyNet.state_dict())
            cur_target = 0
            
            print(i)
        
        while True:
            eps = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * step_count / EPS_DECAY)
            if random.random()< eps:
                act = env.action_space.sample()
            else:
                with torch.no_grad():
                    Q = policyNet(getOneHotTensor(obs, env.observation_space.n))
                    act = Q.data.numpy().argmax()
            
            next_obs, rew, done, _ = env.step(act)
            step_count += 1
            if done:
                rew = rew*4 - 2
            info = stepInfo(obs, act, next_obs, rew)
            
            memory.append(info)
            replay = memory.sample(BATCH)
            
            if replay:
                replay = stepInfo(*zip(*replay))
                
                states = torch.cat(list(map(lambda s:getOneHotTensor(s,env.observation_space.n),replay.cur_state)))
                next_states = torch.cat(list(map(lambda s:getOneHotTensor(s,env.observation_space.n),replay.next_state)))
                actions = torch.cat(list(map(lambda s:getOneHotTensor(s,env.action_space.n),replay.action)))
                rewards = torch.FloatTensor(replay.reward).view(-1,1)#.cuda()
                
                optimizer.zero_grad()
                Qpred = policyNet(states)
                Qtarget = (actions * rewards + GAMMA*targetNet(next_states)).detach()
                
                loss_ = F.smooth_l1_loss(Qpred, Qtarget)
                loss_.backward()
                loss_list.append(loss_.data)
                optimizer.step()
            
            obs = next_obs
            if done:
                if rew > 0:
                    done_size += 1
                    cur_target += 1
                    print("%d, steps = %d, loss = %.4f"%(i,step_count, loss_.data), "Cleared")
                obs = env.reset()
                break
# Out:
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 64, steps = 668, loss = 0.0301 Cleared
# 69, steps = 850, loss = 0.0409 Cleared
# 70
# 80
# 90
# 92, steps = 2672, loss = 0.0063 Cleared
# 100
# 110
# 120
# 121, steps = 4192, loss = 0.0086 Cleared
# 130
# 140
# 146, steps = 4483, loss = 0.0142 Cleared
# 147, steps = 4490, loss = 0.0154 Cleared
# 150
# 156, steps = 4558, loss = 0.0028 Cleared
# 157, steps = 4565, loss = 0.0032 Cleared
# 160
# 165, steps = 4638, loss = 0.0119 Cleared
# 169, steps = 4675, loss = 0.0031 Cleared
# 170
# 180
# 190
# 195, steps = 4812, loss = 0.0167 Cleared
# 200
# 201, steps = 4905, loss = 0.0058 Cleared
# 210
# 216, steps = 5009, loss = 0.0281 Cleared
# 220
# 225, steps = 5139, loss = 0.0171 Cleared
# 230
# 230, steps = 5268, loss = 0.0132 Cleared
# 234, steps = 5330, loss = 0.0293 Cleared
# 240
# 250
# 252, steps = 5628, loss = 0.0146 Cleared
# 260
# 270
# 271, steps = 6119, loss = 0.0268 Cleared
# 274, steps = 6193, loss = 0.0189 Cleared
# 280
# 290
# 294, steps = 6700, loss = 0.0388 Cleared
# 296, steps = 6821, loss = 0.0332 Cleared
# 298, steps = 6882, loss = 0.0242 Cleared
# 300
# 300, steps = 6999, loss = 0.0313 Cleared
# 301, steps = 7024, loss = 0.0224 Cleared
# 310
# 311, steps = 7197, loss = 0.0264 Cleared
# 315, steps = 7348, loss = 0.0307 Cleared
# 319, steps = 7444, loss = 0.0183 Cleared
# 320
# 328, steps = 7630, loss = 0.0289 Cleared
# 330
# 331, steps = 7659, loss = 0.0371 Cleared
# 335, steps = 7714, loss = 0.0267 Cleared
# 336, steps = 7729, loss = 0.0238 Cleared
# 338, steps = 7760, loss = 0.0284 Cleared
# 340
# 343, steps = 7903, loss = 0.0124 Cleared
# 344, steps = 7913, loss = 0.0094 Cleared
# 350
# 354, steps = 8098, loss = 0.0220 Cleared
# 360
# 365, steps = 8329, loss = 0.0238 Cleared
# 367, steps = 8406, loss = 0.0159 Cleared
# 370
# 380
# 385, steps = 8791, loss = 0.0182 Cleared
# 389, steps = 8918, loss = 0.0168 Cleared
# 390
# 400
# 400, steps = 9015, loss = 0.0105 Cleared
# 407, steps = 9104, loss = 0.0070 Cleared
# 410
# 419, steps = 9258, loss = 0.0136 Cleared
# 420
# 421, steps = 9321, loss = 0.0073 Cleared
# 423, steps = 9368, loss = 0.0041 Cleared
# 424, steps = 9387, loss = 0.0118 Cleared
# 426, steps = 9429, loss = 0.0174 Cleared
# 429, steps = 9525, loss = 0.0218 Cleared
# 430
# 432, steps = 9637, loss = 0.0129 Cleared
# 435, steps = 9776, loss = 0.0142 Cleared
# 440
# 440, steps = 9878, loss = 0.0116 Cleared
# 447, steps = 10066, loss = 0.0165 Cleared
# 450
# 451, steps = 10316, loss = 0.0221 Cleared
# 460
# 470
# 470, steps = 11117, loss = 0.0129 Cleared
# 474, steps = 11275, loss = 0.0188 Cleared
# 477, steps = 11320, loss = 0.0207 Cleared
# 478, steps = 11347, loss = 0.0071 Cleared
# 480
# 490
# 498, steps = 11734, loss = 0.0179 Cleared
# 500
# 510
# 520
# 530
# 540
# 550
# 552, steps = 12414, loss = 0.0109 Cleared
# 553, steps = 12434, loss = 0.0120 Cleared
# 559, steps = 12488, loss = 0.0157 Cleared
# 560
# 564, steps = 12511, loss = 0.0057 Cleared
# 570
# 580
# 582, steps = 12660, loss = 0.0177 Cleared
# 590
# 596, steps = 12736, loss = 0.0268 Cleared
# 600
# 610
# 615, steps = 12853, loss = 0.0234 Cleared
# 620
# 623, steps = 12981, loss = 0.0241 Cleared
# 630
# 640
# 640, steps = 13223, loss = 0.0298 Cleared
# 641, steps = 13232, loss = 0.0262 Cleared
# 650
# 660
# 663, steps = 13828, loss = 0.0208 Cleared
# 664, steps = 13886, loss = 0.0167 Cleared
# 668, steps = 14146, loss = 0.0304 Cleared
# 670
# 673, steps = 14420, loss = 0.0327 Cleared
# 680
# 684, steps = 14864, loss = 0.0225 Cleared
# 688, steps = 15005, loss = 0.0349 Cleared
# 689, steps = 15025, loss = 0.0287 Cleared
# 690
# 690, steps = 15032, loss = 0.0223 Cleared
# 698, steps = 15204, loss = 0.0259 Cleared
# 700
# 705, steps = 15386, loss = 0.0204 Cleared
# 709, steps = 15537, loss = 0.0109 Cleared
# 710
# 711, steps = 15606, loss = 0.0192 Cleared
# 712, steps = 15627, loss = 0.0174 Cleared
# 720
# 725, steps = 15997, loss = 0.0081 Cleared
# 726, steps = 16051, loss = 0.0127 Cleared
# 728, steps = 16094, loss = 0.0172 Cleared
# 729, steps = 16120, loss = 0.0098 Cleared
# 730
# 735, steps = 16172, loss = 0.0112 Cleared
# 738, steps = 16217, loss = 0.0128 Cleared
# 740
# 743, steps = 16306, loss = 0.0161 Cleared
# 750
# 760
# 763, steps = 16644, loss = 0.0178 Cleared
# 770
# 780
# 788, steps = 16921, loss = 0.0278 Cleared
# 790
# 800
# 810
# 820
# 830
# 840
# 850
# 860
# 870
# 875, steps = 17768, loss = 0.0414 Cleared
# 876, steps = 17801, loss = 0.0253 Cleared
# 880
# 880, steps = 17880, loss = 0.0236 Cleared
# 890
# 891, steps = 18090, loss = 0.0268 Cleared
# 892, steps = 18107, loss = 0.0292 Cleared
# 893, steps = 18135, loss = 0.0200 Cleared
# 897, steps = 18253, loss = 0.0131 Cleared
# 900
# 910
# 920
# 922, steps = 18913, loss = 0.0301 Cleared
# 930
# 931, steps = 19181, loss = 0.0263 Cleared
# 933, steps = 19252, loss = 0.0230 Cleared
# 936, steps = 19383, loss = 0.0198 Cleared
# 938, steps = 19415, loss = 0.0216 Cleared
# 939, steps = 19461, loss = 0.0307 Cleared
# 940
# 940, steps = 19478, loss = 0.0241 Cleared
# 941, steps = 19508, loss = 0.0291 Cleared
# 944, steps = 19577, loss = 0.0149 Cleared
# 945, steps = 19644, loss = 0.0224 Cleared
# 947, steps = 19686, loss = 0.0178 Cleared
# 948, steps = 19719, loss = 0.0274 Cleared
# 949, steps = 19748, loss = 0.0155 Cleared
# 950
# 950, steps = 19773, loss = 0.0402 Cleared
# 951, steps = 19783, loss = 0.0234 Cleared
# 952, steps = 19800, loss = 0.0228 Cleared
# 953, steps = 19837, loss = 0.0240 Cleared
# 955, steps = 19927, loss = 0.0213 Cleared
# 958, steps = 20021, loss = 0.0254 Cleared
# 959, steps = 20051, loss = 0.0142 Cleared
# 960
# 960, steps = 20073, loss = 0.0095 Cleared
# 964, steps = 20296, loss = 0.0164 Cleared
# 965, steps = 20357, loss = 0.0164 Cleared
# 966, steps = 20385, loss = 0.0077 Cleared
# 967, steps = 20405, loss = 0.0186 Cleared
# 968, steps = 20426, loss = 0.0106 Cleared
# 970
# 974, steps = 20578, loss = 0.0080 Cleared
# 980
# 984, steps = 20872, loss = 0.0135 Cleared
# 990
# 992, steps = 20976, loss = 0.0138 Cleared
# 993, steps = 20985, loss = 0.0115 Cleared
# 999, steps = 21128, loss = 0.0234 Cleared
# 1000
# 1000, steps = 21142, loss = 0.0038 Cleared
# 1004, steps = 21195, loss = 0.0119 Cleared
# 1010
# 1014, steps = 21375, loss = 0.0177 Cleared
# 1019, steps = 21443, loss = 0.0168 Cleared
# 1020
# 1030
# 1040
# 1048, steps = 21709, loss = 0.0190 Cleared
# 1050
# 1060
# 1070
# 1080
# 1082, steps = 22002, loss = 0.0262 Cleared
# 1090
# 1100
# 1102, steps = 22432, loss = 0.0319 Cleared
# 1110
# 1119, steps = 22625, loss = 0.0281 Cleared
# 1120
# 1121, steps = 22667, loss = 0.0220 Cleared
# 1123, steps = 22721, loss = 0.0218 Cleared
# 1130
# 1130, steps = 22847, loss = 0.0219 Cleared
# 1131, steps = 22884, loss = 0.0254 Cleared
# 1134, steps = 23000, loss = 0.0216 Cleared
# 1136, steps = 23019, loss = 0.0253 Cleared
# 1137, steps = 23031, loss = 0.0294 Cleared
# 1140
# 1150
# 1160
# 1161, steps = 23580, loss = 0.0282 Cleared
# 1164, steps = 23653, loss = 0.0212 Cleared
# 1169, steps = 23830, loss = 0.0248 Cleared
# 1170
# 1180
# 1189, steps = 24076, loss = 0.0246 Cleared
# 1190
# 1191, steps = 24118, loss = 0.0345 Cleared
# 1200
# 1201, steps = 24259, loss = 0.0203 Cleared
# 1206, steps = 24295, loss = 0.0274 Cleared
# 1207, steps = 24316, loss = 0.0265 Cleared
# 1209, steps = 24370, loss = 0.0282 Cleared
# 1210
# 1210, steps = 24423, loss = 0.0251 Cleared
# 1212, steps = 24543, loss = 0.0201 Cleared
# 1220
# 1230
# 1231, steps = 25672, loss = 0.0150 Cleared
# 1240
# 1240, steps = 25816, loss = 0.0161 Cleared
# 1250
# 1251, steps = 25979, loss = 0.0132 Cleared
# 1259, steps = 26072, loss = 0.0085 Cleared
# 1260
# 1266, steps = 26131, loss = 0.0148 Cleared
# 1270
# 1272, steps = 26226, loss = 0.0287 Cleared
# 1280
# 1290
# 1291, steps = 26484, loss = 0.0166 Cleared
# 1300
# 1310
# 1317, steps = 26812, loss = 0.0177 Cleared
# 1320
# 1323, steps = 26932, loss = 0.0141 Cleared
# 1330
# 1337, steps = 27311, loss = 0.0190 Cleared
# 1339, steps = 27373, loss = 0.0168 Cleared
# 1340
# 1340, steps = 27471, loss = 0.0245 Cleared
# 1341, steps = 27487, loss = 0.0092 Cleared
# 1344, steps = 27535, loss = 0.0216 Cleared
# 1347, steps = 27611, loss = 0.0240 Cleared
# 1348, steps = 27633, loss = 0.0050 Cleared
# 1349, steps = 27657, loss = 0.0217 Cleared
# 1350
# 1350, steps = 27669, loss = 0.0144 Cleared
# 1357, steps = 27827, loss = 0.0192 Cleared
# 1358, steps = 27852, loss = 0.0182 Cleared
# 1360
# 1362, steps = 27947, loss = 0.0290 Cleared
# 1367, steps = 28169, loss = 0.0188 Cleared
# 1370
# 1376, steps = 28526, loss = 0.0183 Cleared
# 1377, steps = 28548, loss = 0.0254 Cleared
# 1380
# 1382, steps = 28691, loss = 0.0241 Cleared
# 1387, steps = 28765, loss = 0.0110 Cleared
# 1390
# 1395, steps = 28947, loss = 0.0140 Cleared
# 1400
# 1400, steps = 29178, loss = 0.0178 Cleared
# 1410
# 1410, steps = 29626, loss = 0.0225 Cleared
# 1420
# 1430
# 1440
# 1450
# 1457, steps = 30938, loss = 0.0123 Cleared
# 1460
# 1470
# 1470, steps = 31098, loss = 0.0171 Cleared
# 1474, steps = 31170, loss = 0.0073 Cleared
# 1477, steps = 31253, loss = 0.0183 Cleared
# 1478, steps = 31269, loss = 0.0241 Cleared
# 1479, steps = 31281, loss = 0.0187 Cleared
# 1480
# 1482, steps = 31369, loss = 0.0174 Cleared
# 1490
# 1500
# 1503, steps = 31755, loss = 0.0172 Cleared
# 1506, steps = 31931, loss = 0.0128 Cleared
# 1507, steps = 31970, loss = 0.0070 Cleared
# 1509, steps = 32004, loss = 0.0177 Cleared
# 1510
# 1520
# 1521, steps = 32220, loss = 0.0142 Cleared
# 1530
# 1535, steps = 32448, loss = 0.0237 Cleared
# 1539, steps = 32511, loss = 0.0145 Cleared
# 1540
# 1546, steps = 32618, loss = 0.0198 Cleared
# 1550
# 1552, steps = 32674, loss = 0.0139 Cleared
# 1554, steps = 32699, loss = 0.0200 Cleared
# 1560
# 1570
# 1570, steps = 32917, loss = 0.0170 Cleared
# 1580
# 1590
# 1600
# 1601, steps = 33292, loss = 0.0210 Cleared
# 1610
# 1620
# 1623, steps = 33532, loss = 0.0254 Cleared
# 1629, steps = 33618, loss = 0.0302 Cleared
# 1630
# 1640
# 1650
# 1652, steps = 33855, loss = 0.0359 Cleared
# 1653, steps = 33867, loss = 0.0192 Cleared
# 1658, steps = 33923, loss = 0.0270 Cleared
# 1660
# 1662, steps = 34030, loss = 0.0197 Cleared
# 1663, steps = 34075, loss = 0.0182 Cleared
# 1667, steps = 34114, loss = 0.0135 Cleared
# 1670
# 1670, steps = 34141, loss = 0.0320 Cleared
# 1671, steps = 34156, loss = 0.0212 Cleared
# 1677, steps = 34199, loss = 0.0371 Cleared
# 1680
# 1689, steps = 34309, loss = 0.0356 Cleared
# 1690
# 1696, steps = 34386, loss = 0.0270 Cleared
# 1700
# 1708, steps = 34480, loss = 0.0241 Cleared
# 1710
# 1717, steps = 34531, loss = 0.0379 Cleared
# 1720
# 1730
# 1731, steps = 34642, loss = 0.0277 Cleared
# 1733, steps = 34683, loss = 0.0352 Cleared
# 1740
# 1750
# 1754, steps = 34924, loss = 0.0325 Cleared
# 1760
# 1760, steps = 35018, loss = 0.0260 Cleared
# 1766, steps = 35069, loss = 0.0312 Cleared
# 1767, steps = 35108, loss = 0.0192 Cleared
# 1770
# 1777, steps = 35237, loss = 0.0420 Cleared
# 1780
# 1789, steps = 35418, loss = 0.0308 Cleared
# 1790
# 1791, steps = 35502, loss = 0.0244 Cleared
# 1793, steps = 35531, loss = 0.0345 Cleared
# 1795, steps = 35566, loss = 0.0193 Cleared
# 1800
# 1801, steps = 35695, loss = 0.0379 Cleared
# 1802, steps = 35728, loss = 0.0412 Cleared
# 1810
# 1816, steps = 36040, loss = 0.0371 Cleared
# 1820
# 1825, steps = 36341, loss = 0.0219 Cleared
# 1830
# 1838, steps = 36700, loss = 0.0390 Cleared
# 1840
# 1840, steps = 36747, loss = 0.0284 Cleared
# 1843, steps = 36801, loss = 0.0423 Cleared
# 1849, steps = 36881, loss = 0.0193 Cleared
# 1850
# 1860
# 1860, steps = 37125, loss = 0.0353 Cleared
# 1870
# 1875, steps = 37372, loss = 0.0162 Cleared
# 1880
# 1882, steps = 37538, loss = 0.0220 Cleared
# 1886, steps = 37642, loss = 0.0198 Cleared
# 1890
# 1892, steps = 37766, loss = 0.0211 Cleared
# 1894, steps = 37829, loss = 0.0164 Cleared
# 1899, steps = 37875, loss = 0.0202 Cleared
# 1900
# 1900, steps = 37898, loss = 0.0208 Cleared
# 1905, steps = 37980, loss = 0.0193 Cleared
# 1910
# 1920
# 1921, steps = 38296, loss = 0.0237 Cleared
# 1924, steps = 38344, loss = 0.0178 Cleared
# 1930
# 1931, steps = 38520, loss = 0.0327 Cleared
# 1932, steps = 38568, loss = 0.0164 Cleared
# 1934, steps = 38701, loss = 0.0170 Cleared
# 1935, steps = 38717, loss = 0.0213 Cleared
# 1938, steps = 38799, loss = 0.0279 Cleared
# 1940
# 1940, steps = 38880, loss = 0.0107 Cleared
# 1941, steps = 38909, loss = 0.0249 Cleared
# 1943, steps = 38958, loss = 0.0076 Cleared
# 1945, steps = 38985, loss = 0.0186 Cleared
# 1946, steps = 39016, loss = 0.0193 Cleared
# 1950
# 1951, steps = 39139, loss = 0.0216 Cleared
# 1953, steps = 39176, loss = 0.0234 Cleared
# 1960
# 1961, steps = 39345, loss = 0.0284 Cleared
# 1962, steps = 39354, loss = 0.0150 Cleared
# 1965, steps = 39425, loss = 0.0188 Cleared
# 1966, steps = 39463, loss = 0.0288 Cleared
# 1968, steps = 39488, loss = 0.0086 Cleared
# 1970
# 1970, steps = 39557, loss = 0.0086 Cleared
# 1973, steps = 39619, loss = 0.0241 Cleared
# 1980
# 1989, steps = 39972, loss = 0.0064 Cleared
# 1990
# 1992, steps = 40006, loss = 0.0233 Cleared
# 1994, steps = 40056, loss = 0.0136 Cleared
# 1996, steps = 40123, loss = 0.0265 Cleared
# 1997, steps = 40134, loss = 0.0197 Cleared

# %%
for i in range(16):
    with torch.no_grad():
        print(policyNet(getOneHotTensor(i,16)).max(1)[1])
# Out:
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([3])

# %%
for i in range(16):
    with torch.no_grad():
        print(targetNet(getOneHotTensor(i,16)).max(1)[1])
# Out:
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([2])
# tensor([0])
# tensor([2])
# tensor([2])
# tensor([3])

# %%
done_size
# Out:
# 270
